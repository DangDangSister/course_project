# %% [markdown]
# # Deep Neural Netrowk Model - DEAP Arousal emotion (Three Classes)

# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt
import time
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.models import load_model
from keras import metrics
from keras import regularizers
import models.nnmodels as nn
import utils.data as data

import gc
gc.enable()
seed = 0
np.random.seed(seed)
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Load data for three classes classification

# %%
print 'Loading DEAP dataset...'
subject_data_folds, valence_folds, arousal_folds = data.load_deap(32, 3)
print 'DEAP dataset is loaded.\n'

print 5*'#' + ' Dataset representation for each subject ' + 5*'#'
print '\nThere are {} subjects in the dataset.\n'.format(len(subject_data_folds))
print '(Trail/Video, Channel, Readings) : ', subject_data_folds[0].shape
print '(Trail/Video, label (valence or arousal)) : ', arousal_folds[0].shape
# Out:
# Loading DEAP dataset...
# DEAP dataset is loaded.
#
# ##### Dataset representation for each subject #####
#
# There are 32 subjects in the dataset.
#
# (Trail/Video, Channel, Readings) :  (40, 40, 8064)
# (Trail/Video, label (valence or arousal)) :  (40, 3)

# %% [markdown]
# # Reduce the features dimention (8064D >> 101D)
# ## Then Normalize the features

# %%
# Reduce the features dimension
print 'Mapping features into Gaussian with mean zero and unit variance...'
reduced_data_folds = data.normalize_features(subject_data_folds, flag=True)
print 'Normalization done.'
# Out:
# Mapping features into Gaussian with mean zero and unit variance...
# Normalization done.

# %% [markdown]
# # Train DNN model for three classes (low Arousal / mid Arousal / High Arousal) classification

# %%
num_subjects = 32
batch_size = 250
epochs = 250
num_exp = 40
num_classes = 3



accuracies= []

print '##### Three Classes Classification for Arousal emotion Using Deep Neural Network #####\n'

for s in np.arange(0, num_subjects):
    
    
    X_val = reduced_data_folds[s]
    y_val = arousal_folds[s]
    
    X_remaining_folds = reduced_data_folds[:s] + reduced_data_folds[s+1:]
    y_remaining_folds = arousal_folds[:s] + arousal_folds[s+1:]
    
    X_train = np.concatenate(X_remaining_folds)
    y_train = np.concatenate(y_remaining_folds)
 
   

    key = 's'+str(s+1).zfill(2)+'_Arousal(3classes)'
      
    # Arousal classification model for three classes    
    model = nn.DNN(num_classes=num_classes)
    
    # checkpoint
    filepath="../saved_models/best_model_for_{}.h5".format(key)
    
    print 'Training model to test on subject {} ...\n'.format(str(s+1).zfill(2))
    
    checkpoint = ModelCheckpoint(filepath, monitor='val_categorical_accuracy',
                                verbose=1, save_best_only=True, mode='max', period=20)
    callbacks_list = [checkpoint]
    
    hist = model.fit(X_train, y_train, 
             batch_size=batch_size,
             epochs=epochs,
             shuffle=True,
             verbose=0,
             validation_data=(X_val, y_val), callbacks=callbacks_list)
    
    
    
    model.load_weights(filepath)
    
    scores = model.evaluate(x=X_val, y=y_val)
    
    
    
    print '#### Result of DNN model for subject {} #####\n'.format(str(s+1).zfill(2))
    print "Loss: {} , Accuracy : {}%".format(scores[0], scores[1]*100)
    
    

    accuracies.append(scores[1])
    # summarize history for accuracy
    plt.plot(hist.history['categorical_accuracy'])
    plt.plot(hist.history['val_categorical_accuracy'])
    plt.title('Subject ' +str(s+1).zfill(2)+ ' DNN model accuracy for Arousal')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    
    
    # summarize history for loss
    plt.plot(hist.history['loss'])
    plt.plot(hist.history['val_loss'])
    plt.title('Subject ' +str(s+1).zfill(2)+ ' DNN model loss for Arousal')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

    del model
# Out:
# ##### Three Classes Classification for Arousal emotion Using Deep Neural Network #####
#
# Training model to test on subject 01 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.35000, saving model to ../saved_models/best_model_for_s01_Arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 198us/step
# #### Result of DNN model for subject 01 #####
#
# Loss: 1.06883299351 , Accuracy : 35.0%
# Training model to test on subject 02 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.42500, saving model to ../saved_models/best_model_for_s02_Arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy improved from 0.42500 to 0.47500, saving model to ../saved_models/best_model_for_s02_Arousal(3classes).h5
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 194us/step
# #### Result of DNN model for subject 02 #####
#
# Loss: 1.10890069008 , Accuracy : 47.5%
# Training model to test on subject 03 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.40000, saving model to ../saved_models/best_model_for_s03_Arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 206us/step
# #### Result of DNN model for subject 03 #####
#
# Loss: 1.09719908237 , Accuracy : 40.0%
# Training model to test on subject 04 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.25000, saving model to ../saved_models/best_model_for_s04_Arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy improved from 0.25000 to 0.27500, saving model to ../saved_models/best_model_for_s04_Arousal(3classes).h5
# Epoch 00140: val_categorical_accuracy improved from 0.27500 to 0.30000, saving model to ../saved_models/best_model_for_s04_Arousal(3classes).h5
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 191us/step
# #### Result of DNN model for subject 04 #####
#
# Loss: 1.48779950142 , Accuracy : 30.0%
# Training model to test on subject 05 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.40000, saving model to ../saved_models/best_model_for_s05_Arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 192us/step
# #### Result of DNN model for subject 05 #####
#
# Loss: 1.10534069538 , Accuracy : 40.0%
# Training model to test on subject 06 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.35000, saving model to ../saved_models/best_model_for_s06_Arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 192us/step
# #### Result of DNN model for subject 06 #####
#
# Loss: 1.12777540684 , Accuracy : 35.0%
# Training model to test on subject 07 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.47500, saving model to ../saved_models/best_model_for_s07_Arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 191us/step
# #### Result of DNN model for subject 07 #####
#
# Loss: 1.05548696518 , Accuracy : 47.5%
# Training model to test on subject 08 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.20000, saving model to ../saved_models/best_model_for_s08_Arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.20000 to 0.27500, saving model to ../saved_models/best_model_for_s08_Arousal(3classes).h5
# Epoch 00060: val_categorical_accuracy improved from 0.27500 to 0.35000, saving model to ../saved_models/best_model_for_s08_Arousal(3classes).h5
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy improved from 0.35000 to 0.37500, saving model to ../saved_models/best_model_for_s08_Arousal(3classes).h5
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy improved from 0.37500 to 0.40000, saving model to ../saved_models/best_model_for_s08_Arousal(3classes).h5
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 200us/step
# #### Result of DNN model for subject 08 #####
#
# Loss: 1.15039294958 , Accuracy : 40.0%
# Training model to test on subject 09 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.50000, saving model to ../saved_models/best_model_for_s09_Arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.50000 to 0.52500, saving model to ../saved_models/best_model_for_s09_Arousal(3classes).h5
# Epoch 00060: val_categorical_accuracy improved from 0.52500 to 0.55000, saving model to ../saved_models/best_model_for_s09_Arousal(3classes).h5
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 189us/step
# #### Result of DNN model for subject 09 #####
#
# Loss: 0.977616763115 , Accuracy : 55.0%
# Training model to test on subject 10 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.20000, saving model to ../saved_models/best_model_for_s10_Arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy improved from 0.20000 to 0.25000, saving model to ../saved_models/best_model_for_s10_Arousal(3classes).h5
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy improved from 0.25000 to 0.30000, saving model to ../saved_models/best_model_for_s10_Arousal(3classes).h5
# Epoch 00180: val_categorical_accuracy improved from 0.30000 to 0.32500, saving model to ../saved_models/best_model_for_s10_Arousal(3classes).h5
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 191us/step
# #### Result of DNN model for subject 10 #####
#
# Loss: 1.34333992004 , Accuracy : 32.5%
# Training model to test on subject 11 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.30000, saving model to ../saved_models/best_model_for_s11_Arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 196us/step
# #### Result of DNN model for subject 11 #####
#
# Loss: 1.85577687025 , Accuracy : 30.0%
# Training model to test on subject 12 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.62500, saving model to ../saved_models/best_model_for_s12_Arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 195us/step
# #### Result of DNN model for subject 12 #####
#
# Loss: 1.01471245289 , Accuracy : 62.5%
# Training model to test on subject 13 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.57500, saving model to ../saved_models/best_model_for_s13_Arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy improved from 0.57500 to 0.62500, saving model to ../saved_models/best_model_for_s13_Arousal(3classes).h5
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 194us/step
# #### Result of DNN model for subject 13 #####
#
# Loss: 0.984032845497 , Accuracy : 62.5%
# Training model to test on subject 14 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.22500, saving model to ../saved_models/best_model_for_s14_Arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy improved from 0.22500 to 0.25000, saving model to ../saved_models/best_model_for_s14_Arousal(3classes).h5
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 197us/step
# #### Result of DNN model for subject 14 #####
#
# Loss: 1.20111461878 , Accuracy : 25.0%
# Training model to test on subject 15 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.22500, saving model to ../saved_models/best_model_for_s15_Arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.22500 to 0.32500, saving model to ../saved_models/best_model_for_s15_Arousal(3classes).h5
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy improved from 0.32500 to 0.35000, saving model to ../saved_models/best_model_for_s15_Arousal(3classes).h5
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 197us/step
# #### Result of DNN model for subject 15 #####
#
# Loss: 1.12697479725 , Accuracy : 35.0%
# Training model to test on subject 16 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.35000, saving model to ../saved_models/best_model_for_s16_Arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 200us/step
# #### Result of DNN model for subject 16 #####
#
# Loss: 1.12094624043 , Accuracy : 35.0%
# Training model to test on subject 17 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.35000, saving model to ../saved_models/best_model_for_s17_Arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.35000 to 0.37500, saving model to ../saved_models/best_model_for_s17_Arousal(3classes).h5
# Epoch 00060: val_categorical_accuracy improved from 0.37500 to 0.47500, saving model to ../saved_models/best_model_for_s17_Arousal(3classes).h5
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy improved from 0.47500 to 0.52500, saving model to ../saved_models/best_model_for_s17_Arousal(3classes).h5
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 202us/step
# #### Result of DNN model for subject 17 #####
#
# Loss: 1.0764375329 , Accuracy : 52.5%
# Training model to test on subject 18 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.17500, saving model to ../saved_models/best_model_for_s18_Arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy improved from 0.17500 to 0.20000, saving model to ../saved_models/best_model_for_s18_Arousal(3classes).h5
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 194us/step
# #### Result of DNN model for subject 18 #####
#
# Loss: 1.15479450226 , Accuracy : 20.0%
# Training model to test on subject 19 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.50000, saving model to ../saved_models/best_model_for_s19_Arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 217us/step
# #### Result of DNN model for subject 19 #####
#
# Loss: 1.05084841251 , Accuracy : 50.0%
# Training model to test on subject 20 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.32500, saving model to ../saved_models/best_model_for_s20_Arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy improved from 0.32500 to 0.37500, saving model to ../saved_models/best_model_for_s20_Arousal(3classes).h5
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 206us/step
# #### Result of DNN model for subject 20 #####
#
# Loss: 1.09012422562 , Accuracy : 37.5%
# Training model to test on subject 21 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.62500, saving model to ../saved_models/best_model_for_s21_Arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.62500 to 0.65000, saving model to ../saved_models/best_model_for_s21_Arousal(3classes).h5
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 208us/step
# #### Result of DNN model for subject 21 #####
#
# Loss: 0.962783622742 , Accuracy : 65.0%
# Training model to test on subject 22 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.50000, saving model to ../saved_models/best_model_for_s22_Arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 202us/step
# #### Result of DNN model for subject 22 #####
#
# Loss: 1.40187132359 , Accuracy : 50.0%
# Training model to test on subject 23 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.20000, saving model to ../saved_models/best_model_for_s23_Arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy improved from 0.20000 to 0.22500, saving model to ../saved_models/best_model_for_s23_Arousal(3classes).h5
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy improved from 0.22500 to 0.27500, saving model to ../saved_models/best_model_for_s23_Arousal(3classes).h5
# Epoch 00200: val_categorical_accuracy improved from 0.27500 to 0.30000, saving model to ../saved_models/best_model_for_s23_Arousal(3classes).h5
# Epoch 00220: val_categorical_accuracy improved from 0.30000 to 0.32500, saving model to ../saved_models/best_model_for_s23_Arousal(3classes).h5
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 214us/step
# #### Result of DNN model for subject 23 #####
#
# Loss: 1.46873161793 , Accuracy : 32.5%
# Training model to test on subject 24 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.47500, saving model to ../saved_models/best_model_for_s24_Arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.47500 to 0.52500, saving model to ../saved_models/best_model_for_s24_Arousal(3classes).h5
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 209us/step
# #### Result of DNN model for subject 24 #####
#
# Loss: 0.984140014648 , Accuracy : 52.5%
# Training model to test on subject 25 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.55000, saving model to ../saved_models/best_model_for_s25_Arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy improved from 0.55000 to 0.57500, saving model to ../saved_models/best_model_for_s25_Arousal(3classes).h5
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 208us/step
# #### Result of DNN model for subject 25 #####
#
# Loss: 1.08284246922 , Accuracy : 57.5%
# Training model to test on subject 26 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.32500, saving model to ../saved_models/best_model_for_s26_Arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy improved from 0.32500 to 0.35000, saving model to ../saved_models/best_model_for_s26_Arousal(3classes).h5
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 213us/step
# #### Result of DNN model for subject 26 #####
#
# Loss: 1.25758590698 , Accuracy : 35.0%
# Training model to test on subject 27 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.35000, saving model to ../saved_models/best_model_for_s27_Arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy improved from 0.35000 to 0.40000, saving model to ../saved_models/best_model_for_s27_Arousal(3classes).h5
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 221us/step
# #### Result of DNN model for subject 27 #####
#
# Loss: 1.08226308823 , Accuracy : 40.0%
# Training model to test on subject 28 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.32500, saving model to ../saved_models/best_model_for_s28_Arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 222us/step
# #### Result of DNN model for subject 28 #####
#
# Loss: 1.22659621239 , Accuracy : 32.5%
# Training model to test on subject 29 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.50000, saving model to ../saved_models/best_model_for_s29_Arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 221us/step
# #### Result of DNN model for subject 29 #####
#
# Loss: 1.05664393902 , Accuracy : 50.0%
# Training model to test on subject 30 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.30000, saving model to ../saved_models/best_model_for_s30_Arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 208us/step
# #### Result of DNN model for subject 30 #####
#
# Loss: 1.17551856041 , Accuracy : 30.0%
# Training model to test on subject 31 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.37500, saving model to ../saved_models/best_model_for_s31_Arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 207us/step
# #### Result of DNN model for subject 31 #####
#
# Loss: 1.14759464264 , Accuracy : 37.5%
# Training model to test on subject 32 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.35000, saving model to ../saved_models/best_model_for_s32_Arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.35000 to 0.42500, saving model to ../saved_models/best_model_for_s32_Arousal(3classes).h5
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 199us/step
# #### Result of DNN model for subject 32 #####
#
# Loss: 1.12679729462 , Accuracy : 42.5%

# %% [markdown]
# # Accuracies

# %%
min_acc_subject_idx, max_acc_subject_idx = np.argmin(accuracies), np.argmax(accuracies)

avg_acc =  reduce(lambda x, y: x + y, accuracies) / len(accuracies)

print 5*'#' + ' Accuracies per subject ' + 5*'#'

print 'Subject {} has the minimum accuracy : {}%'.format(min_acc_subject_idx + 1, min(accuracies)*100)
print 'Subject {} has the maximum accuracy : {}%'.format(max_acc_subject_idx + 1, max(accuracies)*100)
print 'Average accuracy : {}%'.format(avg_acc*100)

for subj in enumerate(accuracies):
    print 'Accuracy of Subject {} : {}%'.format(subj[0]+1, subj[1]*100)
# Out:
# ##### Accuracies per subject #####
# Subject 18 has the minimum accuracy : 20.0%
# Subject 21 has the maximum accuracy : 65.0%
# Average accuracy : 41.796875%
# Accuracy of Subject 1 : 35.0%
# Accuracy of Subject 2 : 47.5%
# Accuracy of Subject 3 : 40.0%
# Accuracy of Subject 4 : 30.0%
# Accuracy of Subject 5 : 40.0%
# Accuracy of Subject 6 : 35.0%
# Accuracy of Subject 7 : 47.5%
# Accuracy of Subject 8 : 40.0%
# Accuracy of Subject 9 : 55.0%
# Accuracy of Subject 10 : 32.5%
# Accuracy of Subject 11 : 30.0%
# Accuracy of Subject 12 : 62.5%
# Accuracy of Subject 13 : 62.5%
# Accuracy of Subject 14 : 25.0%
# Accuracy of Subject 15 : 35.0%
# Accuracy of Subject 16 : 35.0%
# Accuracy of Subject 17 : 52.5%
# Accuracy of Subject 18 : 20.0%
# Accuracy of Subject 19 : 50.0%
# Accuracy of Subject 20 : 37.5%
# Accuracy of Subject 21 : 65.0%
# Accuracy of Subject 22 : 50.0%
# Accuracy of Subject 23 : 32.5%
# Accuracy of Subject 24 : 52.5%
# Accuracy of Subject 25 : 57.5%
# Accuracy of Subject 26 : 35.0%
# Accuracy of Subject 27 : 40.0%
# Accuracy of Subject 28 : 32.5%
# Accuracy of Subject 29 : 50.0%
# Accuracy of Subject 30 : 30.0%
# Accuracy of Subject 31 : 37.5%
# Accuracy of Subject 32 : 42.5%
