# %% [markdown]
# # Deep Neural Netrowk Model - DEAP Valence emotion (Two Classes)

# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt
import time
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.models import load_model
from keras import metrics
from keras import regularizers
import models.nnmodels as nn
import utils.data as data

import gc
gc.enable()
seed = 0
np.random.seed(seed)
# %matplotlib inline

# uncomment this block to set limit on GPU usage
"""
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.6
#config.gpu_options.visible_device_list = "0"
set_session(tf.Session(config=config))
"""
# Out:
# Using TensorFlow backend.
# '\nimport tensorflow as tf\nfrom keras.backend.tensorflow_backend import set_session\nconfig = tf.ConfigProto()\nconfig.gpu_options.per_process_gpu_memory_fraction = 0.6\n#config.gpu_options.visible_device_list = "0"\nset_session(tf.Session(config=config))\n'

# %% [markdown]
# # Load data for two classes classification

# %%
print 'Loading DEAP dataset...'
subject_data_folds, valence_folds, arousal_folds = data.load_deap(32, 2)
print 'DEAP dataset is loaded.\n'

print 5*'#' + ' Dataset representation for each subject ' + 5*'#'
print '\nThere are {} subjects in the dataset.\n'.format(len(subject_data_folds))
print '(Trail/Video, Channel, Readings) : ', subject_data_folds[0].shape
print '(Trail/Video, label (valence or arousal)) : ', arousal_folds[0].shape
# Out:
# Loading DEAP dataset...
# DEAP dataset is loaded.
#
# ##### Dataset representation for each subject #####
#
# There are 32 subjects in the dataset.
#
# (Trail/Video, Channel, Readings) :  (40, 40, 8064)
# (Trail/Video, label (valence or arousal)) :  (40, 2)

# %% [markdown]
# # Reduce the features dimention (8064D >> 101D)
# ## Then Normalize the features

# %%
# Reduce the features dimension
print 'Mapping features into Gaussian with mean zero and unit variance...'
reduced_data_folds = data.normalize_features(subject_data_folds, flag=True)
print 'Normalization done.'
# Out:
# Mapping features into Gaussian with mean zero and unit variance...
# Normalization done.

# %% [markdown]
# # Train DNN model for two classes (low Valence / High Valence) classification

# %%
num_subjects = 32
batch_size = 310
epochs = 250
num_exp = 40
num_classes = 2



accuracies= []

print '##### Two Classes Classification for Valence emotion Using Deep Neural Network #####\n'

start = time.time()
for s in np.arange(0, num_subjects):
    
    
    X_val = reduced_data_folds[s]
    y_val = valence_folds[s]
    
    X_remaining_folds = reduced_data_folds[:s] + reduced_data_folds[s+1:]
    y_remaining_folds = valence_folds[:s] + valence_folds[s+1:]
    
    X_train = np.concatenate(X_remaining_folds)
    y_train = np.concatenate(y_remaining_folds)
 
   

    key = 's'+str(s+1).zfill(2)+'_valence(2classes)'
      
    # Valence classification model for two classes    
    model = nn.DNN(num_classes=2)
    
    # checkpoint
    filepath="../saved_models/best_model_for_{}.h5".format(key)
    
    print 'Training model to test on subject {} ...\n'.format(str(s+1).zfill(2))
    
    checkpoint = ModelCheckpoint(filepath, monitor='val_categorical_accuracy',
                                verbose=1, save_best_only=True, mode='max', period=50)
    callbacks_list = [checkpoint]
    
    hist = model.fit(X_train, y_train, 
             batch_size=batch_size,
             epochs=epochs,
             shuffle=True,
             verbose=0,
             validation_data=(X_val, y_val), callbacks=callbacks_list)
    
    
    
    model.load_weights(filepath)
    
    scores = model.evaluate(x=X_val, y=y_val)
    
    
    
    print '#### Result of DNN model for subject {} #####\n'.format(str(s+1).zfill(2))
    print "Loss: {} , Accuracy : {}%".format(scores[0], scores[1]*100)
    
    

    accuracies.append(scores[1])
    # summarize history for accuracy
    plt.plot(hist.history['categorical_accuracy'])
    plt.plot(hist.history['val_categorical_accuracy'])
    plt.title('Subject ' +str(s+1).zfill(2)+ ' DNN model accuracy for Valence')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    
    
    # summarize history for loss
    plt.plot(hist.history['loss'])
    plt.plot(hist.history['val_loss'])
    plt.title('Subject ' +str(s+1).zfill(2)+ ' DNN model loss for Valence')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

    del model
print 'finished training at, ', time.time() - start
# Out:
# ##### Two Classes Classification for Valence emotion Using Deep Neural Network #####
#
# Training model to test on subject 01 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.67500, saving model to ../saved_models/best_model_for_s01_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00150: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00250: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 197us/step
# #### Result of DNN model for subject 01 #####
#
# Loss: 0.674171769619 , Accuracy : 67.5%
# Training model to test on subject 02 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.67500, saving model to ../saved_models/best_model_for_s02_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy improved from 0.67500 to 0.72500, saving model to ../saved_models/best_model_for_s02_valence(2classes).h5
# Epoch 00150: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy improved from 0.72500 to 0.75000, saving model to ../saved_models/best_model_for_s02_valence(2classes).h5
# Epoch 00250: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 185us/step
# #### Result of DNN model for subject 02 #####
#
# Loss: 0.60103495121 , Accuracy : 75.0%
# Training model to test on subject 03 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.75000, saving model to ../saved_models/best_model_for_s03_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy improved from 0.75000 to 0.77500, saving model to ../saved_models/best_model_for_s03_valence(2classes).h5
# Epoch 00150: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00250: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 192us/step
# #### Result of DNN model for subject 03 #####
#
# Loss: 0.565921449661 , Accuracy : 77.5%
# Training model to test on subject 04 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.60000, saving model to ../saved_models/best_model_for_s04_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy improved from 0.60000 to 0.67500, saving model to ../saved_models/best_model_for_s04_valence(2classes).h5
# Epoch 00150: val_categorical_accuracy improved from 0.67500 to 0.70000, saving model to ../saved_models/best_model_for_s04_valence(2classes).h5
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00250: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 188us/step
# #### Result of DNN model for subject 04 #####
#
# Loss: 0.843762242794 , Accuracy : 70.0%
# Training model to test on subject 05 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.67500, saving model to ../saved_models/best_model_for_s05_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00150: val_categorical_accuracy improved from 0.67500 to 0.75000, saving model to ../saved_models/best_model_for_s05_valence(2classes).h5
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00250: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 206us/step
# #### Result of DNN model for subject 05 #####
#
# Loss: 0.666336393356 , Accuracy : 75.0%
# Training model to test on subject 06 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.75000, saving model to ../saved_models/best_model_for_s06_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00150: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00250: val_categorical_accuracy improved from 0.75000 to 0.77500, saving model to ../saved_models/best_model_for_s06_valence(2classes).h5
# 40/40 [==============================] - 0s 189us/step
# #### Result of DNN model for subject 06 #####
#
# Loss: 0.593204128742 , Accuracy : 77.5%
# Training model to test on subject 07 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.70000, saving model to ../saved_models/best_model_for_s07_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00150: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00250: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 203us/step
# #### Result of DNN model for subject 07 #####
#
# Loss: 0.661693048477 , Accuracy : 70.0%
# Training model to test on subject 08 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.70000, saving model to ../saved_models/best_model_for_s08_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00150: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00250: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 185us/step
# #### Result of DNN model for subject 08 #####
#
# Loss: 0.615292990208 , Accuracy : 70.0%
# Training model to test on subject 09 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.75000, saving model to ../saved_models/best_model_for_s09_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00150: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00250: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 196us/step
# #### Result of DNN model for subject 09 #####
#
# Loss: 0.567163598537 , Accuracy : 75.0%
# Training model to test on subject 10 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.80000, saving model to ../saved_models/best_model_for_s10_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00150: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00250: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 228us/step
# #### Result of DNN model for subject 10 #####
#
# Loss: 0.525505185127 , Accuracy : 80.0%
# Training model to test on subject 11 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.45000, saving model to ../saved_models/best_model_for_s11_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy improved from 0.45000 to 0.52500, saving model to ../saved_models/best_model_for_s11_valence(2classes).h5
# Epoch 00150: val_categorical_accuracy improved from 0.52500 to 0.60000, saving model to ../saved_models/best_model_for_s11_valence(2classes).h5
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00250: val_categorical_accuracy improved from 0.60000 to 0.65000, saving model to ../saved_models/best_model_for_s11_valence(2classes).h5
# 40/40 [==============================] - 0s 201us/step
# #### Result of DNN model for subject 11 #####
#
# Loss: 0.820673847198 , Accuracy : 65.0%
# Training model to test on subject 12 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.72500, saving model to ../saved_models/best_model_for_s12_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy improved from 0.72500 to 0.77500, saving model to ../saved_models/best_model_for_s12_valence(2classes).h5
# Epoch 00150: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00250: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 203us/step
# #### Result of DNN model for subject 12 #####
#
# Loss: 0.574514508247 , Accuracy : 77.5%
# Training model to test on subject 13 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.75000, saving model to ../saved_models/best_model_for_s13_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00150: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00250: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 217us/step
# #### Result of DNN model for subject 13 #####
#
# Loss: 0.557365524769 , Accuracy : 75.0%
# Training model to test on subject 14 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.85000, saving model to ../saved_models/best_model_for_s14_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00150: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00250: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 212us/step
# #### Result of DNN model for subject 14 #####
#
# Loss: 0.527622830868 , Accuracy : 85.0%
# Training model to test on subject 15 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.77500, saving model to ../saved_models/best_model_for_s15_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00150: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00250: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 204us/step
# #### Result of DNN model for subject 15 #####
#
# Loss: 0.454855406284 , Accuracy : 77.5%
# Training model to test on subject 16 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.50000, saving model to ../saved_models/best_model_for_s16_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00150: val_categorical_accuracy improved from 0.50000 to 0.55000, saving model to ../saved_models/best_model_for_s16_valence(2classes).h5
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00250: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 200us/step
# #### Result of DNN model for subject 16 #####
#
# Loss: 0.968199682236 , Accuracy : 55.0%
# Training model to test on subject 17 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.75000, saving model to ../saved_models/best_model_for_s17_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy improved from 0.75000 to 0.82500, saving model to ../saved_models/best_model_for_s17_valence(2classes).h5
# Epoch 00150: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00250: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 201us/step
# #### Result of DNN model for subject 17 #####
#
# Loss: 0.54454126358 , Accuracy : 82.5%
# Training model to test on subject 18 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.80000, saving model to ../saved_models/best_model_for_s18_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00150: val_categorical_accuracy improved from 0.80000 to 0.85000, saving model to ../saved_models/best_model_for_s18_valence(2classes).h5
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00250: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 209us/step
# #### Result of DNN model for subject 18 #####
#
# Loss: 0.453819769621 , Accuracy : 85.0%
# Training model to test on subject 19 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.77500, saving model to ../saved_models/best_model_for_s19_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00150: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00250: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 195us/step
# #### Result of DNN model for subject 19 #####
#
# Loss: 0.51345205307 , Accuracy : 77.5%
# Training model to test on subject 20 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.92500, saving model to ../saved_models/best_model_for_s20_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00150: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00250: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 197us/step
# #### Result of DNN model for subject 20 #####
#
# Loss: 0.408524274826 , Accuracy : 92.5%
# Training model to test on subject 21 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.67500, saving model to ../saved_models/best_model_for_s21_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy improved from 0.67500 to 0.72500, saving model to ../saved_models/best_model_for_s21_valence(2classes).h5
# Epoch 00150: val_categorical_accuracy improved from 0.72500 to 0.75000, saving model to ../saved_models/best_model_for_s21_valence(2classes).h5
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00250: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 207us/step
# #### Result of DNN model for subject 21 #####
#
# Loss: 0.606233489513 , Accuracy : 75.0%
# Training model to test on subject 22 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.77500, saving model to ../saved_models/best_model_for_s22_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00150: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00250: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 199us/step
# #### Result of DNN model for subject 22 #####
#
# Loss: 0.565210819244 , Accuracy : 77.5%
# Training model to test on subject 23 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.70000, saving model to ../saved_models/best_model_for_s23_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy improved from 0.70000 to 0.75000, saving model to ../saved_models/best_model_for_s23_valence(2classes).h5
# Epoch 00150: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00250: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 203us/step
# #### Result of DNN model for subject 23 #####
#
# Loss: 0.541603910923 , Accuracy : 75.0%
# Training model to test on subject 24 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.77500, saving model to ../saved_models/best_model_for_s24_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy improved from 0.77500 to 0.80000, saving model to ../saved_models/best_model_for_s24_valence(2classes).h5
# Epoch 00150: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00250: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 213us/step
# #### Result of DNN model for subject 24 #####
#
# Loss: 0.493635344505 , Accuracy : 80.0%
# Training model to test on subject 25 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.67500, saving model to ../saved_models/best_model_for_s25_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00150: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00250: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 209us/step
# #### Result of DNN model for subject 25 #####
#
# Loss: 0.623779928684 , Accuracy : 67.5%
# Training model to test on subject 26 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.62500, saving model to ../saved_models/best_model_for_s26_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00150: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00250: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 202us/step
# #### Result of DNN model for subject 26 #####
#
# Loss: 0.576803135872 , Accuracy : 62.5%
# Training model to test on subject 27 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.57500, saving model to ../saved_models/best_model_for_s27_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy improved from 0.57500 to 0.60000, saving model to ../saved_models/best_model_for_s27_valence(2classes).h5
# Epoch 00150: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00250: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 203us/step
# #### Result of DNN model for subject 27 #####
#
# Loss: 0.712314581871 , Accuracy : 60.0%
# Training model to test on subject 28 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.72500, saving model to ../saved_models/best_model_for_s28_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy improved from 0.72500 to 0.77500, saving model to ../saved_models/best_model_for_s28_valence(2classes).h5
# Epoch 00150: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy improved from 0.77500 to 0.80000, saving model to ../saved_models/best_model_for_s28_valence(2classes).h5
# Epoch 00250: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 212us/step
# #### Result of DNN model for subject 28 #####
#
# Loss: 0.434568405151 , Accuracy : 80.0%
# Training model to test on subject 29 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.72500, saving model to ../saved_models/best_model_for_s29_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy improved from 0.72500 to 0.75000, saving model to ../saved_models/best_model_for_s29_valence(2classes).h5
# Epoch 00150: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00250: val_categorical_accuracy improved from 0.75000 to 0.77500, saving model to ../saved_models/best_model_for_s29_valence(2classes).h5
# 40/40 [==============================] - 0s 221us/step
# #### Result of DNN model for subject 29 #####
#
# Loss: 0.567695212364 , Accuracy : 77.5%
# Training model to test on subject 30 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.65000, saving model to ../saved_models/best_model_for_s30_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy improved from 0.65000 to 0.67500, saving model to ../saved_models/best_model_for_s30_valence(2classes).h5
# Epoch 00150: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00250: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 204us/step
# #### Result of DNN model for subject 30 #####
#
# Loss: 0.624423325062 , Accuracy : 67.5%
# Training model to test on subject 31 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.77500, saving model to ../saved_models/best_model_for_s31_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy improved from 0.77500 to 0.80000, saving model to ../saved_models/best_model_for_s31_valence(2classes).h5
# Epoch 00150: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00250: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 200us/step
# #### Result of DNN model for subject 31 #####
#
# Loss: 0.498598361015 , Accuracy : 80.0%
# Training model to test on subject 32 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.77500, saving model to ../saved_models/best_model_for_s32_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00150: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00250: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 208us/step
# #### Result of DNN model for subject 32 #####
#
# Loss: 0.587288188934 , Accuracy : 77.5%
# finished training at,  -1481.90023708

# %% [markdown]
# # Accuracies

# %%
min_acc_subject_idx, max_acc_subject_idx = np.argmin(accuracies), np.argmax(accuracies)

avg_acc =  reduce(lambda x, y: x + y, accuracies) / len(accuracies)

print 5*'#' + ' Accuracies per subject ' + 5*'#'

print 'Subject {} has the minimum accuracy : {}%'.format(min_acc_subject_idx + 1, min(accuracies)*100)
print 'Subject {} has the maximum accuracy : {}%'.format(max_acc_subject_idx + 1, max(accuracies)*100)
print 'Average accuracy : {}%'.format(avg_acc*100)

for subj in enumerate(accuracies):
    print 'Accuracy of Subject {} : {}'.format(subj[0]+1, subj[1]*100)
# Out:
# ##### Accuracies per subject #####
# Subject 16 has the minimum accuracy : 55.0%
# Subject 20 has the maximum accuracy : 92.5%
# Average accuracy : 74.6875%
# Accuracy of Subject 1 : 67.5
# Accuracy of Subject 2 : 75.0
# Accuracy of Subject 3 : 77.5
# Accuracy of Subject 4 : 70.0
# Accuracy of Subject 5 : 75.0
# Accuracy of Subject 6 : 77.5
# Accuracy of Subject 7 : 70.0
# Accuracy of Subject 8 : 70.0
# Accuracy of Subject 9 : 75.0
# Accuracy of Subject 10 : 80.0
# Accuracy of Subject 11 : 65.0
# Accuracy of Subject 12 : 77.5
# Accuracy of Subject 13 : 75.0
# Accuracy of Subject 14 : 85.0
# Accuracy of Subject 15 : 77.5
# Accuracy of Subject 16 : 55.0
# Accuracy of Subject 17 : 82.5
# Accuracy of Subject 18 : 85.0
# Accuracy of Subject 19 : 77.5
# Accuracy of Subject 20 : 92.5
# Accuracy of Subject 21 : 75.0
# Accuracy of Subject 22 : 77.5
# Accuracy of Subject 23 : 75.0
# Accuracy of Subject 24 : 80.0
# Accuracy of Subject 25 : 67.5
# Accuracy of Subject 26 : 62.5
# Accuracy of Subject 27 : 60.0
# Accuracy of Subject 28 : 80.0
# Accuracy of Subject 29 : 77.5
# Accuracy of Subject 30 : 67.5
# Accuracy of Subject 31 : 80.0
# Accuracy of Subject 32 : 77.5
