# %% [markdown]
# # Deep Neural Netrowk Model - DEAP Valence emotion (Two Classes)

# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt
import time
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.models import load_model
from keras import metrics
from keras import regularizers
import models.nnmodels as nn
import utils.data as data

import gc
gc.enable()
seed = 0
np.random.seed(seed)
# %matplotlib inline


import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.5
#config.gpu_options.visible_device_list = "0"
set_session(tf.Session(config=config))
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Load data for two classes classification

# %%
print 'Loading DEAP dataset...'
subject_data_folds, valence_folds, arousal_folds = data.load_deap(32, 2)
print 'DEAP dataset is loaded.\n'

print 5*'#' + ' Dataset representation for each subject ' + 5*'#'
print '\nThere are {} subjects in the dataset.\n'.format(len(subject_data_folds))
print '(Trail/Video, Channel, Readings) : ', subject_data_folds[0].shape
print '(Trail/Video, label (valence or arousal)) : ', arousal_folds[0].shape
# Out:
# Loading DEAP dataset...
# DEAP dataset is loaded.
#
# ##### Dataset representation for each subject #####
#
# There are 32 subjects in the dataset.
#
# (Trail/Video, Channel, Readings) :  (40, 40, 8064)
# (Trail/Video, label (valence or arousal)) :  (40, 2)

# %% [markdown]
# # Reduce the features dimention (8064D >> 101D)
# ## Then Normalize the features

# %%
# Reduce the features dimension
print 'Mapping features into Gaussian with mean zero and unit variance...'
reduced_data_folds = data.normalize_features(subject_data_folds, flag=True)
print 'Normalization done.'
# Out:
# Mapping features into Gaussian with mean zero and unit variance...
# Normalization done.

# %% [markdown]
# # Train DNN model for two classes (low Valence / High Valence) classification

# %%
num_subjects = 32
batch_size = 250
epochs = 100
num_exp = 40
num_classes = 2



accuracies= []

print '##### Two Classes Classification for Valence emotion Using Deep Neural Network #####\n'

start = time.time()
for s in np.arange(0, num_subjects):
    
    
    X_val = reduced_data_folds[s]
    y_val = valence_folds[s]
    
    X_remaining_folds = reduced_data_folds[:s] + reduced_data_folds[s+1:]
    y_remaining_folds = valence_folds[:s] + valence_folds[s+1:]
    
    X_train = np.concatenate(X_remaining_folds)
    y_train = np.concatenate(y_remaining_folds)
 
   

    key = 's'+str(s+1).zfill(2)+'_valence(2classes)'
      
    # Valence classification model for two classes    
    model = nn.DNN(num_classes=2)
    
    # checkpoint
    filepath="../saved_models/best_model_for_{}.h5".format(key)
    
    print 'Training model to test on subject {} ...\n'.format(str(s+1).zfill(2))
    
    checkpoint = ModelCheckpoint(filepath, monitor='val_categorical_accuracy',
                                verbose=1, save_best_only=True, mode='max', period=50)
    callbacks_list = [checkpoint]
    
    hist = model.fit(X_train, y_train, 
             batch_size=batch_size,
             epochs=epochs,
             shuffle=True,
             verbose=0,
             validation_data=(X_val, y_val), callbacks=callbacks_list)
    
    
    
    model.load_weights(filepath)
    
    scores = model.evaluate(x=X_val, y=y_val)
    
    
    
    print '#### Result of DNN model for subject {} #####\n'.format(str(s+1).zfill(2))
    print "Loss: {} , Accuracy : {}%".format(scores[0], scores[1]*100)
    
    

    accuracies.append(scores[1])
    # summarize history for accuracy
    plt.plot(hist.history['categorical_accuracy'])
    plt.plot(hist.history['val_categorical_accuracy'])
    plt.title('Subject ' +str(s+1).zfill(2)+ ' DNN model accuracy for Valence')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    
    
    # summarize history for loss
    plt.plot(hist.history['loss'])
    plt.plot(hist.history['val_loss'])
    plt.title('Subject ' +str(s+1).zfill(2)+ ' DNN model loss for Valence')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

    del model
print 'finished training at, ', start - time.time()
# Out:
# ##### Two Classes Classification for Valence emotion Using Deep Neural Network #####
#
# Training model to test on subject 01 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.67500, saving model to ../saved_models/best_model_for_s01_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 222us/step
# #### Result of DNN model for subject 01 #####
#
# Loss: 0.709630727768 , Accuracy : 67.5%
# Training model to test on subject 02 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.57500, saving model to ../saved_models/best_model_for_s02_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy improved from 0.57500 to 0.65000, saving model to ../saved_models/best_model_for_s02_valence(2classes).h5
# 40/40 [==============================] - 0s 286us/step
# #### Result of DNN model for subject 02 #####
#
# Loss: 0.593866455555 , Accuracy : 65.0%
# Training model to test on subject 03 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.72500, saving model to ../saved_models/best_model_for_s03_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 195us/step
# #### Result of DNN model for subject 03 #####
#
# Loss: 0.578596305847 , Accuracy : 72.5%
# Training model to test on subject 04 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.65000, saving model to ../saved_models/best_model_for_s04_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 156us/step
# #### Result of DNN model for subject 04 #####
#
# Loss: 0.725143885612 , Accuracy : 65.0%
# Training model to test on subject 05 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.70000, saving model to ../saved_models/best_model_for_s05_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 160us/step
# #### Result of DNN model for subject 05 #####
#
# Loss: 0.620683145523 , Accuracy : 70.0%
# Training model to test on subject 06 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.72500, saving model to ../saved_models/best_model_for_s06_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy improved from 0.72500 to 0.75000, saving model to ../saved_models/best_model_for_s06_valence(2classes).h5
# 40/40 [==============================] - 0s 156us/step
# #### Result of DNN model for subject 06 #####
#
# Loss: 0.6103916049 , Accuracy : 75.0%
# Training model to test on subject 07 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.62500, saving model to ../saved_models/best_model_for_s07_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy improved from 0.62500 to 0.65000, saving model to ../saved_models/best_model_for_s07_valence(2classes).h5
# 40/40 [==============================] - 0s 215us/step
# #### Result of DNN model for subject 07 #####
#
# Loss: 0.819831895828 , Accuracy : 65.0%
# Training model to test on subject 08 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.72500, saving model to ../saved_models/best_model_for_s08_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 208us/step
# #### Result of DNN model for subject 08 #####
#
# Loss: 0.629977416992 , Accuracy : 72.5%
# Training model to test on subject 09 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.72500, saving model to ../saved_models/best_model_for_s09_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy improved from 0.72500 to 0.75000, saving model to ../saved_models/best_model_for_s09_valence(2classes).h5
# 40/40 [==============================] - 0s 522us/step
# #### Result of DNN model for subject 09 #####
#
# Loss: 0.568845796585 , Accuracy : 75.0%
# Training model to test on subject 10 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.67500, saving model to ../saved_models/best_model_for_s10_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy improved from 0.67500 to 0.75000, saving model to ../saved_models/best_model_for_s10_valence(2classes).h5
# 40/40 [==============================] - 0s 453us/step
# #### Result of DNN model for subject 10 #####
#
# Loss: 0.537826681137 , Accuracy : 75.0%
# Training model to test on subject 11 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.60000, saving model to ../saved_models/best_model_for_s11_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy improved from 0.60000 to 0.72500, saving model to ../saved_models/best_model_for_s11_valence(2classes).h5
# 40/40 [==============================] - 0s 250us/step
# #### Result of DNN model for subject 11 #####
#
# Loss: 0.532595974207 , Accuracy : 72.5%
# Training model to test on subject 12 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.75000, saving model to ../saved_models/best_model_for_s12_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy improved from 0.75000 to 0.80000, saving model to ../saved_models/best_model_for_s12_valence(2classes).h5
# 40/40 [==============================] - 0s 371us/step
# #### Result of DNN model for subject 12 #####
#
# Loss: 0.547298574448 , Accuracy : 80.0%
# Training model to test on subject 13 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.70000, saving model to ../saved_models/best_model_for_s13_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy improved from 0.70000 to 0.72500, saving model to ../saved_models/best_model_for_s13_valence(2classes).h5
# 40/40 [==============================] - 0s 203us/step
# #### Result of DNN model for subject 13 #####
#
# Loss: 0.565604516864 , Accuracy : 72.5%
# Training model to test on subject 14 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.80000, saving model to ../saved_models/best_model_for_s14_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 183us/step
# #### Result of DNN model for subject 14 #####
#
# Loss: 0.589186489582 , Accuracy : 80.0%
# Training model to test on subject 15 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.80000, saving model to ../saved_models/best_model_for_s15_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 536us/step
# #### Result of DNN model for subject 15 #####
#
# Loss: 0.468729358912 , Accuracy : 80.0%
# Training model to test on subject 16 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.55000, saving model to ../saved_models/best_model_for_s16_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 436us/step
# #### Result of DNN model for subject 16 #####
#
# Loss: 0.855578315258 , Accuracy : 55.0%
# Training model to test on subject 17 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.72500, saving model to ../saved_models/best_model_for_s17_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy improved from 0.72500 to 0.77500, saving model to ../saved_models/best_model_for_s17_valence(2classes).h5
# 40/40 [==============================] - 0s 263us/step
# #### Result of DNN model for subject 17 #####
#
# Loss: 0.548377323151 , Accuracy : 77.5%
# Training model to test on subject 18 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.77500, saving model to ../saved_models/best_model_for_s18_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 191us/step
# #### Result of DNN model for subject 18 #####
#
# Loss: 0.475327426195 , Accuracy : 77.5%
# Training model to test on subject 19 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.80000, saving model to ../saved_models/best_model_for_s19_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 295us/step
# #### Result of DNN model for subject 19 #####
#
# Loss: 0.462384867668 , Accuracy : 80.0%
# Training model to test on subject 20 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.87500, saving model to ../saved_models/best_model_for_s20_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 294us/step
# #### Result of DNN model for subject 20 #####
#
# Loss: 0.422819334269 , Accuracy : 87.5%
# Training model to test on subject 21 ...
#
# Epoch 00050: val_categorical_accuracy improved from -inf to 0.85000, saving model to ../saved_models/best_model_for_s21_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 444us/step
# #### Result of DNN model for subject 21 #####
#
# Loss: 0.574782109261 , Accuracy : 85.0%
# Training model to test on subject 22 ...
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-4-d957c7d1bf20> in <module>()
#      45              shuffle=True,
#      46              verbose=0,
# ---> 47              validation_data=(X_val, y_val), callbacks=callbacks_list)
#      48
#      49
#
# /storage/omid/venv2/lib/python2.7/site-packages/Keras-2.1.2-py2.7.egg/keras/models.pyc in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#     970                               initial_epoch=initial_epoch,
#     971                               steps_per_epoch=steps_per_epoch,
# --> 972                               validation_steps=validation_steps)
#     973
#     974     def evaluate(self, x=None, y=None,
#
# /storage/omid/venv2/lib/python2.7/site-packages/Keras-2.1.2-py2.7.egg/keras/engine/training.pyc in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1655                               initial_epoch=initial_epoch,
#    1656                               steps_per_epoch=steps_per_epoch,
# -> 1657                               validation_steps=validation_steps)
#    1658
#    1659     def evaluate(self, x=None, y=None,
#
# /storage/omid/venv2/lib/python2.7/site-packages/Keras-2.1.2-py2.7.egg/keras/engine/training.pyc in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1211                     batch_logs['size'] = len(batch_ids)
#    1212                     callbacks.on_batch_begin(batch_index, batch_logs)
# -> 1213                     outs = f(ins_batch)
#    1214                     if not isinstance(outs, list):
#    1215                         outs = [outs]
#
# /storage/omid/venv2/lib/python2.7/site-packages/Keras-2.1.2-py2.7.egg/keras/backend/tensorflow_backend.pyc in __call__(self, inputs)
#    2458         session = get_session()
#    2459         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2460                               **self.session_kwargs)
#    2461         return updated[:len(self.outputs)]
#    2462
#
# /storage/omid/venv2/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /storage/omid/venv2/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# /storage/omid/venv2/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /storage/omid/venv2/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1334         except KeyError:
#    1335           pass
# -> 1336       raise type(e)(node_def, op, message)
#    1337
#    1338   def _extend_graph(self):
#
# ResourceExhaustedError: OOM when allocating tensor with shape[4040,5000]
# 	 [[Node: training_21/RMSprop/Square = Square[T=DT_FLOAT, _device="/job:localhost/replica:0/task:0/device:GPU:0"](training_21/RMSprop/gradients/dense_85/MatMul_grad/MatMul_1)]]
#
# Caused by op u'training_21/RMSprop/Square', defined at:
#   File "/usr/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/usr/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/storage/omid/venv2/lib/python2.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/storage/omid/venv2/local/lib/python2.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/storage/omid/venv2/local/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "/storage/omid/venv2/local/lib/python2.7/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/storage/omid/venv2/local/lib/python2.7/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/storage/omid/venv2/local/lib/python2.7/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/storage/omid/venv2/local/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/storage/omid/venv2/local/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/storage/omid/venv2/local/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/storage/omid/venv2/local/lib/python2.7/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/storage/omid/venv2/local/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 281, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/storage/omid/venv2/local/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 232, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/storage/omid/venv2/local/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 397, in execute_request
#     user_expressions, allow_stdin)
#   File "/storage/omid/venv2/local/lib/python2.7/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/storage/omid/venv2/local/lib/python2.7/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/storage/omid/venv2/local/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/storage/omid/venv2/local/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/storage/omid/venv2/local/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-4-d957c7d1bf20>", line 47, in <module>
#     validation_data=(X_val, y_val), callbacks=callbacks_list)
#   File "build/bdist.linux-x86_64/egg/keras/models.py", line 972, in fit
#     validation_steps=validation_steps)
#   File "build/bdist.linux-x86_64/egg/keras/engine/training.py", line 1634, in fit
#     self._make_train_function()
#   File "build/bdist.linux-x86_64/egg/keras/engine/training.py", line 990, in _make_train_function
#     loss=self.total_loss)
#   File "build/bdist.linux-x86_64/egg/keras/legacy/interfaces.py", line 87, in wrapper
#     return func(*args, **kwargs)
#   File "build/bdist.linux-x86_64/egg/keras/optimizers.py", line 240, in get_updates
#     new_a = self.rho * a + (1. - self.rho) * K.square(g)
#   File "build/bdist.linux-x86_64/egg/keras/backend/tensorflow_backend.py", line 1425, in square
#     return tf.square(x)
#   File "/storage/omid/venv2/local/lib/python2.7/site-packages/tensorflow/python/ops/math_ops.py", line 449, in square
#     return gen_math_ops.square(x, name=name)
#   File "/storage/omid/venv2/local/lib/python2.7/site-packages/tensorflow/python/ops/gen_math_ops.py", line 4567, in square
#     "Square", x=x, name=name)
#   File "/storage/omid/venv2/local/lib/python2.7/site-packages/tensorflow/python/framework/op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "/storage/omid/venv2/local/lib/python2.7/site-packages/tensorflow/python/framework/ops.py", line 2956, in create_op
#     op_def=op_def)
#   File "/storage/omid/venv2/local/lib/python2.7/site-packages/tensorflow/python/framework/ops.py", line 1470, in __init__
#     self._traceback = self._graph._extract_stack()  # pylint: disable=protected-access
#
# ResourceExhaustedError (see above for traceback): OOM when allocating tensor with shape[4040,5000]
# 	 [[Node: training_21/RMSprop/Square = Square[T=DT_FLOAT, _device="/job:localhost/replica:0/task:0/device:GPU:0"](training_21/RMSprop/gradients/dense_85/MatMul_grad/MatMul_1)]]

# %% [markdown]
# # Accuracies

# %%
min_acc_subject_idx, max_acc_subject_idx = argmin(accuracies), np.argmax(accuracies)

avg_acc =  reduce(lambda x, y: x + y, accuracies) / len(accuracies)

print 5*'#' + ' Accuracies per subject ' + 5*'#'

print 'Subject {} has the minimum accuracy : {}'.format(min_acc_subject_idx + 1, min(accuracies))
print 'Subject {} has the maximum accuracy : {}'.format(max_acc_subject_idx + 1, max(accuracies))

for subj in enumerate(accuracies):
    print 'Accuracy of Subject {} : {}'.format(subj+1, accuracies[subj])
