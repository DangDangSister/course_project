# %% [markdown]
# # Convolutional Neural Netrowk Model - DEAP Arousal emotion
# # (Three Classes)

# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt
import time
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.models import load_model
from keras import metrics
from keras import regularizers
import models.nnmodels as nn
import utils.data as data

import gc
gc.enable()
seed = 0
np.random.seed(seed)
# %matplotlib inline

"""
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.5
#config.gpu_options.visible_device_list = "0"
set_session(tf.Session(config=config))
"""
# Out:
# Using TensorFlow backend.
# '\nimport tensorflow as tf\nfrom keras.backend.tensorflow_backend import set_session\nconfig = tf.ConfigProto()\nconfig.gpu_options.per_process_gpu_memory_fraction = 0.5\n#config.gpu_options.visible_device_list = "0"\nset_session(tf.Session(config=config))\n'

# %% [markdown]
# # Load data for three classes classification

# %%
print 'Loading DEAP dataset...'
subject_data_folds, valence_folds, arousal_folds = data.load_deap(32, 3)
print 'DEAP dataset is loaded.\n'

print 5*'#' + ' Dataset representation for each subject ' + 5*'#'
print '\nThere are {} subjects in the dataset.\n'.format(len(subject_data_folds))
print '(Trail/Video, Channel, Readings) : ', subject_data_folds[0].shape
print '(Trail/Video, label (valence or arousal)) : ', arousal_folds[0].shape
# Out:
# Loading DEAP dataset...
# DEAP dataset is loaded.
#
# ##### Dataset representation for each subject #####
#
# There are 32 subjects in the dataset.
#
# (Trail/Video, Channel, Readings) :  (40, 40, 8064)
# (Trail/Video, label (valence or arousal)) :  (40, 3)

# %% [markdown]
# # Reduce the features dimention (8064D >> 101D)
# ## Then Normalize the features

# %%
# Reduce the features dimension
print 'Mapping features into Gaussian with mean zero and unit variance...'
reduced_data_folds = data.normalize_features(subject_data_folds, flag=True)
print 'Normalization done.'
# Out:
# Mapping features into Gaussian with mean zero and unit variance...
# Normalization done.

# %% [markdown]
# # Train CNN model for three classes (low Arousal / mid Arousal / High Arousal) classification

# %%
num_exp = 40
num_classes = 3
batch_size = 50
epochs = 250
num_subjects = 32


accuracies= []

print '##### Three Classes Classification for Arousal emotion Using Convolutional Neural Network #####\n'
   

for s in np.arange(0, num_subjects):
    
    
    X_val = reduced_data_folds[s]
    X_val = X_val.reshape(X_val.shape[0], 1, 40, 101)
    y_val = arousal_folds[s]
    
    X_remaining_folds = reduced_data_folds[:s] + reduced_data_folds[s+1:]
    y_remaining_folds = arousal_folds[:s] + arousal_folds[s+1:]
    
    X_train = np.concatenate(X_remaining_folds)
    X_train = X_train.reshape(X_train.shape[0], 1, 40, 101)
    
    y_train = np.concatenate(y_remaining_folds)
    
    
    key = 's'+str(s+1).zfill(2)+'_arousal(3classes)'
    
    
    # arousal classification model for three classes    
    model = nn.CNN(num_classes=num_classes, emotion='arousal')
    
    
    # checkpoint
    filepath="../saved_models/best_CNN_model_for_{}.h5".format(key)
    
    print 'Training model to test on subject {} ...\n'.format(str(s+1).zfill(2))
    
    checkpoint = ModelCheckpoint(filepath, monitor='val_categorical_accuracy',
                                verbose=1, save_best_only=True, mode='max', period=20)
    
    callbacks_list = [checkpoint]
    
    
    hist = model.fit(X_train, y_train, 
             batch_size=batch_size,
             epochs=epochs,
             shuffle=True,
             verbose=0,
             validation_data=(X_val, y_val), callbacks=callbacks_list)

    
    
    model.load_weights(filepath)
    
    scores = model.evaluate(x=X_val, y=y_val)
    
    
    
    print '#### Result of CNN model for subject {} #####\n'.format(str(s+1).zfill(2))
    print "Loss: {} , Accuracy : {}%".format(scores[0], scores[1]*100)
    
    

    accuracies.append(scores[1])
    # summarize history for accuracy
    plt.plot(hist.history['categorical_accuracy'])
    plt.plot(hist.history['val_categorical_accuracy'])
    plt.title('Subject ' +str(s+1).zfill(2)+ ' CNN model accuracy for arousal')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    
    
    # summarize history for loss
    plt.plot(hist.history['loss'])
    plt.plot(hist.history['val_loss'])
    plt.title('Subject ' +str(s+1).zfill(2)+ ' CNN model loss for arousal')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

    del model
# Out:
# ##### Three Classes Classification for Arousal emotion Using Convolutional Neural Network #####
#
# Training model to test on subject 01 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.32500, saving model to ../saved_models/best_CNN_model_for_s01_arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 7ms/step
# #### Result of CNN model for subject 01 #####
#
# Loss: 1.37433285713 , Accuracy : 32.5%
# Training model to test on subject 02 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.40000, saving model to ../saved_models/best_CNN_model_for_s02_arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 676us/step
# #### Result of CNN model for subject 02 #####
#
# Loss: 1.14830369949 , Accuracy : 40.0%
# Training model to test on subject 03 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.45000, saving model to ../saved_models/best_CNN_model_for_s03_arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 695us/step
# #### Result of CNN model for subject 03 #####
#
# Loss: 1.21232280731 , Accuracy : 45.0%
# Training model to test on subject 04 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.27500, saving model to ../saved_models/best_CNN_model_for_s04_arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 702us/step
# #### Result of CNN model for subject 04 #####
#
# Loss: 2.50316476822 , Accuracy : 27.5%
# Training model to test on subject 05 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.40000, saving model to ../saved_models/best_CNN_model_for_s05_arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.40000 to 0.42500, saving model to ../saved_models/best_CNN_model_for_s05_arousal(3classes).h5
# Epoch 00060: val_categorical_accuracy improved from 0.42500 to 0.45000, saving model to ../saved_models/best_CNN_model_for_s05_arousal(3classes).h5
# Epoch 00080: val_categorical_accuracy improved from 0.45000 to 0.47500, saving model to ../saved_models/best_CNN_model_for_s05_arousal(3classes).h5
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy improved from 0.47500 to 0.50000, saving model to ../saved_models/best_CNN_model_for_s05_arousal(3classes).h5
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 712us/step
# #### Result of CNN model for subject 05 #####
#
# Loss: 2.56391682625 , Accuracy : 50.0%
# Training model to test on subject 06 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.22500, saving model to ../saved_models/best_CNN_model_for_s06_arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.22500 to 0.37500, saving model to ../saved_models/best_CNN_model_for_s06_arousal(3classes).h5
# Epoch 00060: val_categorical_accuracy improved from 0.37500 to 0.40000, saving model to ../saved_models/best_CNN_model_for_s06_arousal(3classes).h5
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 722us/step
# #### Result of CNN model for subject 06 #####
#
# Loss: 1.73935899734 , Accuracy : 40.0%
# Training model to test on subject 07 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.55000, saving model to ../saved_models/best_CNN_model_for_s07_arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 697us/step
# #### Result of CNN model for subject 07 #####
#
# Loss: 0.984089422226 , Accuracy : 55.0%
# Training model to test on subject 08 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.32500, saving model to ../saved_models/best_CNN_model_for_s08_arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 696us/step
# #### Result of CNN model for subject 08 #####
#
# Loss: 1.168384552 , Accuracy : 32.5%
# Training model to test on subject 09 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.37500, saving model to ../saved_models/best_CNN_model_for_s09_arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.37500 to 0.42500, saving model to ../saved_models/best_CNN_model_for_s09_arousal(3classes).h5
# Epoch 00060: val_categorical_accuracy improved from 0.42500 to 0.50000, saving model to ../saved_models/best_CNN_model_for_s09_arousal(3classes).h5
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 693us/step
# #### Result of CNN model for subject 09 #####
#
# Loss: 1.17762391567 , Accuracy : 50.0%
# Training model to test on subject 10 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.32500, saving model to ../saved_models/best_CNN_model_for_s10_arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 697us/step
# #### Result of CNN model for subject 10 #####
#
# Loss: 1.2982475996 , Accuracy : 32.5%
# Training model to test on subject 11 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.25000, saving model to ../saved_models/best_CNN_model_for_s11_arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.25000 to 0.30000, saving model to ../saved_models/best_CNN_model_for_s11_arousal(3classes).h5
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 703us/step
# #### Result of CNN model for subject 11 #####
#
# Loss: 2.74407818317 , Accuracy : 30.0%
# Training model to test on subject 12 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.50000, saving model to ../saved_models/best_CNN_model_for_s12_arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 697us/step
# #### Result of CNN model for subject 12 #####
#
# Loss: 0.906881523132 , Accuracy : 50.0%
# Training model to test on subject 13 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.72500, saving model to ../saved_models/best_CNN_model_for_s13_arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 711us/step
# #### Result of CNN model for subject 13 #####
#
# Loss: 0.845832777023 , Accuracy : 72.5%
# Training model to test on subject 14 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.32500, saving model to ../saved_models/best_CNN_model_for_s14_arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.32500 to 0.37500, saving model to ../saved_models/best_CNN_model_for_s14_arousal(3classes).h5
# Epoch 00060: val_categorical_accuracy improved from 0.37500 to 0.40000, saving model to ../saved_models/best_CNN_model_for_s14_arousal(3classes).h5
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 688us/step
# #### Result of CNN model for subject 14 #####
#
# Loss: 1.84096572399 , Accuracy : 40.0%
# Training model to test on subject 15 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.32500, saving model to ../saved_models/best_CNN_model_for_s15_arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy improved from 0.32500 to 0.35000, saving model to ../saved_models/best_CNN_model_for_s15_arousal(3classes).h5
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 697us/step
# #### Result of CNN model for subject 15 #####
#
# Loss: 3.27457036972 , Accuracy : 35.0%
# Training model to test on subject 16 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.25000, saving model to ../saved_models/best_CNN_model_for_s16_arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy improved from 0.25000 to 0.27500, saving model to ../saved_models/best_CNN_model_for_s16_arousal(3classes).h5
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy improved from 0.27500 to 0.35000, saving model to ../saved_models/best_CNN_model_for_s16_arousal(3classes).h5
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 706us/step
# #### Result of CNN model for subject 16 #####
#
# Loss: 2.70230426788 , Accuracy : 35.0%
# Training model to test on subject 17 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.55000, saving model to ../saved_models/best_CNN_model_for_s17_arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.55000 to 0.62500, saving model to ../saved_models/best_CNN_model_for_s17_arousal(3classes).h5
# Epoch 00060: val_categorical_accuracy improved from 0.62500 to 0.65000, saving model to ../saved_models/best_CNN_model_for_s17_arousal(3classes).h5
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 700us/step
# #### Result of CNN model for subject 17 #####
#
# Loss: 1.12800136805 , Accuracy : 65.0%
# Training model to test on subject 18 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.37500, saving model to ../saved_models/best_CNN_model_for_s18_arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 706us/step
# #### Result of CNN model for subject 18 #####
#
# Loss: 1.14494247437 , Accuracy : 37.5%
# Training model to test on subject 19 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.55000, saving model to ../saved_models/best_CNN_model_for_s19_arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 710us/step
# #### Result of CNN model for subject 19 #####
#
# Loss: 1.02750440836 , Accuracy : 55.0%
# Training model to test on subject 20 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.47500, saving model to ../saved_models/best_CNN_model_for_s20_arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy improved from 0.47500 to 0.50000, saving model to ../saved_models/best_CNN_model_for_s20_arousal(3classes).h5
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 685us/step
# #### Result of CNN model for subject 20 #####
#
# Loss: 1.27821879387 , Accuracy : 50.0%
# Training model to test on subject 21 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.15000, saving model to ../saved_models/best_CNN_model_for_s21_arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.15000 to 0.25000, saving model to ../saved_models/best_CNN_model_for_s21_arousal(3classes).h5
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy improved from 0.25000 to 0.27500, saving model to ../saved_models/best_CNN_model_for_s21_arousal(3classes).h5
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 705us/step
# #### Result of CNN model for subject 21 #####
#
# Loss: 2.80151071548 , Accuracy : 27.5%
# Training model to test on subject 22 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.42500, saving model to ../saved_models/best_CNN_model_for_s22_arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.42500 to 0.47500, saving model to ../saved_models/best_CNN_model_for_s22_arousal(3classes).h5
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 706us/step
# #### Result of CNN model for subject 22 #####
#
# Loss: 1.84325437546 , Accuracy : 47.5%
# Training model to test on subject 23 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.60000, saving model to ../saved_models/best_CNN_model_for_s23_arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 712us/step
# #### Result of CNN model for subject 23 #####
#
# Loss: 0.959915018082 , Accuracy : 60.0%
# Training model to test on subject 24 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.40000, saving model to ../saved_models/best_CNN_model_for_s24_arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 711us/step
# #### Result of CNN model for subject 24 #####
#
# Loss: 1.5382566452 , Accuracy : 40.0%
# Training model to test on subject 25 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.55000, saving model to ../saved_models/best_CNN_model_for_s25_arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 707us/step
# #### Result of CNN model for subject 25 #####
#
# Loss: 1.54561491013 , Accuracy : 55.0%
# Training model to test on subject 26 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.30000, saving model to ../saved_models/best_CNN_model_for_s26_arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy improved from 0.30000 to 0.35000, saving model to ../saved_models/best_CNN_model_for_s26_arousal(3classes).h5
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy improved from 0.35000 to 0.37500, saving model to ../saved_models/best_CNN_model_for_s26_arousal(3classes).h5
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 726us/step
# #### Result of CNN model for subject 26 #####
#
# Loss: 4.4131196022 , Accuracy : 37.5%
# Training model to test on subject 27 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.40000, saving model to ../saved_models/best_CNN_model_for_s27_arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.40000 to 0.42500, saving model to ../saved_models/best_CNN_model_for_s27_arousal(3classes).h5
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 734us/step
# #### Result of CNN model for subject 27 #####
#
# Loss: 1.95833296776 , Accuracy : 42.5%
# Training model to test on subject 28 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.30000, saving model to ../saved_models/best_CNN_model_for_s28_arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy improved from 0.30000 to 0.32500, saving model to ../saved_models/best_CNN_model_for_s28_arousal(3classes).h5
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 712us/step
# #### Result of CNN model for subject 28 #####
#
# Loss: 2.12784552574 , Accuracy : 32.5%
# Training model to test on subject 29 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.35000, saving model to ../saved_models/best_CNN_model_for_s29_arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy improved from 0.35000 to 0.40000, saving model to ../saved_models/best_CNN_model_for_s29_arousal(3classes).h5
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 713us/step
# #### Result of CNN model for subject 29 #####
#
# Loss: 1.40326054096 , Accuracy : 40.0%
# Training model to test on subject 30 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.27500, saving model to ../saved_models/best_CNN_model_for_s30_arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.27500 to 0.37500, saving model to ../saved_models/best_CNN_model_for_s30_arousal(3classes).h5
# Epoch 00060: val_categorical_accuracy improved from 0.37500 to 0.40000, saving model to ../saved_models/best_CNN_model_for_s30_arousal(3classes).h5
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 711us/step
# #### Result of CNN model for subject 30 #####
#
# Loss: 1.72579293251 , Accuracy : 40.0%
# Training model to test on subject 31 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.45000, saving model to ../saved_models/best_CNN_model_for_s31_arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 711us/step
# #### Result of CNN model for subject 31 #####
#
# Loss: 1.20513365269 , Accuracy : 45.0%
# Training model to test on subject 32 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.37500, saving model to ../saved_models/best_CNN_model_for_s32_arousal(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy improved from 0.37500 to 0.40000, saving model to ../saved_models/best_CNN_model_for_s32_arousal(3classes).h5
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 704us/step
# #### Result of CNN model for subject 32 #####
#
# Loss: 2.33662774563 , Accuracy : 40.0%

# %% [markdown]
# # Accuracies

# %%
min_acc_subject_idx, max_acc_subject_idx = np.argmin(accuracies), np.argmax(accuracies)

avg_acc =  reduce(lambda x, y: x + y, accuracies) / len(accuracies)

print 5*'#' + ' Accuracies per subject ' + 5*'#'

print 'Subject {} has the minimum accuracy : {}%'.format(min_acc_subject_idx + 1, min(accuracies)*100)
print 'Subject {} has the maximum accuracy : {}%'.format(max_acc_subject_idx + 1, max(accuracies)*100)
print 'Average accuracy : {}%'.format(avg_acc*100)

for subj in enumerate(accuracies):
    print 'Accuracy of Subject {} : {}%'.format(subj[0]+1, subj[1]*100)
# Out:
# ##### Accuracies per subject #####
# Subject 4 has the minimum accuracy : 27.5%
# Subject 13 has the maximum accuracy : 72.5%
# Average accuracy : 43.203125%
# Accuracy of Subject 1 : 32.5%
# Accuracy of Subject 2 : 40.0%
# Accuracy of Subject 3 : 45.0%
# Accuracy of Subject 4 : 27.5%
# Accuracy of Subject 5 : 50.0%
# Accuracy of Subject 6 : 40.0%
# Accuracy of Subject 7 : 55.0%
# Accuracy of Subject 8 : 32.5%
# Accuracy of Subject 9 : 50.0%
# Accuracy of Subject 10 : 32.5%
# Accuracy of Subject 11 : 30.0%
# Accuracy of Subject 12 : 50.0%
# Accuracy of Subject 13 : 72.5%
# Accuracy of Subject 14 : 40.0%
# Accuracy of Subject 15 : 35.0%
# Accuracy of Subject 16 : 35.0%
# Accuracy of Subject 17 : 65.0%
# Accuracy of Subject 18 : 37.5%
# Accuracy of Subject 19 : 55.0%
# Accuracy of Subject 20 : 50.0%
# Accuracy of Subject 21 : 27.5%
# Accuracy of Subject 22 : 47.5%
# Accuracy of Subject 23 : 60.0%
# Accuracy of Subject 24 : 40.0%
# Accuracy of Subject 25 : 55.0%
# Accuracy of Subject 26 : 37.5%
# Accuracy of Subject 27 : 42.5%
# Accuracy of Subject 28 : 32.5%
# Accuracy of Subject 29 : 40.0%
# Accuracy of Subject 30 : 40.0%
# Accuracy of Subject 31 : 45.0%
# Accuracy of Subject 32 : 40.0%
