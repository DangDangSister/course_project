# %% [markdown]
# # Import required libraries

# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt
import time
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.models import load_model
from keras import metrics
from keras import regularizers
import models.nnmodels as nn
import utils.data as data

import gc
gc.enable()
seed = 0
np.random.seed(seed)
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Load data for two classes classification

# %%
print 'Loading DEAP dataset...'
subject_data_folds, valence_folds, arousal_folds = data.load_deap(32, 2)
print 'DEAP dataset is loaded.\n'

print 5*'#' + ' Dataset representation for each subject ' + 5*'#'
print '\nThere are {} subjects in the dataset.\n'.format(len(subject_data_folds))
print '(Trail/Video, Channel, Readings) : ', subject_data_folds[0].shape
print '(Trail/Video, label (valence or arousal)) : ', arousal_folds[0].shape
# Out:
# Loading DEAP dataset...
# DEAP dataset is loaded.
#
# ##### Dataset representation for each subject #####
#
# There are 32 subjects in the dataset.
#
# (Trail/Video, Channel, Readings) :  (40, 40, 8064)
# (Trail/Video, label (valence or arousal)) :  (40, 2)

# %% [markdown]
# # Reduce the features dimention (8064D >> 101D)
# ## Then Normalize the features

# %%
# Reduce the features dimension
print 'Mapping features into Gaussian with mean zero and unit variance...'
reduced_data_folds = data.normalize_features(subject_data_folds, flag=True)
print 'Normalization done.'
# Out:
# Mapping features into Gaussian with mean zero and unit variance...
# Normalization done.

# %% [markdown]
# # Train DNN model for two classes (low Valence / High Valence) classification

# %%
num_subjects = 32
batch_size = 250
epochs = 250
num_exp = 40
num_classes = 2



accuracies= []

print '##### Two Classes Classification for Valence emotion Using Deep Neural Network #####\n'

for s in np.arange(0, num_subjects):
    
    
    X_val = reduced_data_folds[s]
    y_val = valence_folds[s]
    
    X_remaining_folds = reduced_data_folds[:s] + reduced_data_folds[s+1:]
    y_remaining_folds = valence_folds[:s] + valence_folds[s+1:]
    
    X_train = np.concatenate(X_remaining_folds)
    y_train = np.concatenate(y_remaining_folds)
 
   

    key = 's'+str(s+1).zfill(2)+'_valence(2classes)'
      
    # Valence classification model for two classes    
    model = nn.DNN(num_classes=2)
    
    # checkpoint
    filepath="../saved_models/best_model_for_{}.h5".format(key)
    
    print 'Training model to test on subject {} ...\n'.format(str(s+1).zfill(2))
    
    checkpoint = ModelCheckpoint(filepath, monitor='val_categorical_accuracy',
                                verbose=1, save_best_only=True, mode='max', period=20)
    callbacks_list = [checkpoint]
    
    hist = model.fit(X_train, y_train, 
             batch_size=batch_size,
             epochs=epochs,
             shuffle=True,
             verbose=0,
             validation_data=(X_val, y_val), callbacks=callbacks_list)
    
    
    
    model.load_weights(filepath)
    
    scores = model.evaluate(x=X_val, y=y_val)
    
    
    
    print '#### Result of DNN model for subject {} #####\n'.format(str(s+1).zfill(2))
    print "Loss: {} , Accuracy : {}%".format(scores[0], scores[1]*100)
    
    

    accuracies.append(scores[1])
    # summarize history for accuracy
    plt.plot(hist.history['categorical_accuracy'])
    plt.plot(hist.history['val_categorical_accuracy'])
    plt.title('Subject ' +str(s+1).zfill(2)+ ' DNN model accuracy for Valence')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    
    
    # summarize history for loss
    plt.plot(hist.history['loss'])
    plt.plot(hist.history['val_loss'])
    plt.title('Subject ' +str(s+1).zfill(2)+ ' DNN model loss for Valence')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

    del model
# Out:
# ##### Two Classes Classification for Valence emotion Using Deep Neural Network #####
#
# Training model to test on subject 01 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.60000, saving model to ../saved_models/best_model_for_s01_valence(2classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.60000 to 0.67500, saving model to ../saved_models/best_model_for_s01_valence(2classes).h5
# Epoch 00060: val_categorical_accuracy improved from 0.67500 to 0.72500, saving model to ../saved_models/best_model_for_s01_valence(2classes).h5
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 173us/step
# #### Result of DNN model for subject 01 #####
#
# Loss: 0.693528968096 , Accuracy : 72.5
# Training model to test on subject 02 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.65000, saving model to ../saved_models/best_model_for_s02_valence(2classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.65000 to 0.75000, saving model to ../saved_models/best_model_for_s02_valence(2classes).h5
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy improved from 0.75000 to 0.77500, saving model to ../saved_models/best_model_for_s02_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy improved from 0.77500 to 0.80000, saving model to ../saved_models/best_model_for_s02_valence(2classes).h5
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy improved from 0.80000 to 0.82500, saving model to ../saved_models/best_model_for_s02_valence(2classes).h5
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 195us/step
# #### Result of DNN model for subject 02 #####
#
# Loss: 0.639833176136 , Accuracy : 82.5
# Training model to test on subject 03 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.72500, saving model to ../saved_models/best_model_for_s03_valence(2classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 169us/step
# #### Result of DNN model for subject 03 #####
#
# Loss: 0.564551949501 , Accuracy : 72.5
# Training model to test on subject 04 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.57500, saving model to ../saved_models/best_model_for_s04_valence(2classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.57500 to 0.65000, saving model to ../saved_models/best_model_for_s04_valence(2classes).h5
# Epoch 00060: val_categorical_accuracy improved from 0.65000 to 0.70000, saving model to ../saved_models/best_model_for_s04_valence(2classes).h5
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 179us/step
# #### Result of DNN model for subject 04 #####
#
# Loss: 0.703155684471 , Accuracy : 70.0
# Training model to test on subject 05 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.62500, saving model to ../saved_models/best_model_for_s05_valence(2classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.62500 to 0.67500, saving model to ../saved_models/best_model_for_s05_valence(2classes).h5
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy improved from 0.67500 to 0.70000, saving model to ../saved_models/best_model_for_s05_valence(2classes).h5
# 40/40 [==============================] - 0s 182us/step
# #### Result of DNN model for subject 05 #####
#
# Loss: 0.866241514683 , Accuracy : 70.0
# Training model to test on subject 06 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.67500, saving model to ../saved_models/best_model_for_s06_valence(2classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy improved from 0.67500 to 0.70000, saving model to ../saved_models/best_model_for_s06_valence(2classes).h5
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy improved from 0.70000 to 0.72500, saving model to ../saved_models/best_model_for_s06_valence(2classes).h5
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 185us/step
# #### Result of DNN model for subject 06 #####
#
# Loss: 0.636890912056 , Accuracy : 72.5
# Training model to test on subject 07 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.67500, saving model to ../saved_models/best_model_for_s07_valence(2classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.67500 to 0.70000, saving model to ../saved_models/best_model_for_s07_valence(2classes).h5
# Epoch 00060: val_categorical_accuracy improved from 0.70000 to 0.72500, saving model to ../saved_models/best_model_for_s07_valence(2classes).h5
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 178us/step
# #### Result of DNN model for subject 07 #####
#
# Loss: 0.677186441422 , Accuracy : 72.5
# Training model to test on subject 08 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.72500, saving model to ../saved_models/best_model_for_s08_valence(2classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.72500 to 0.77500, saving model to ../saved_models/best_model_for_s08_valence(2classes).h5
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 185us/step
# #### Result of DNN model for subject 08 #####
#
# Loss: 0.592241334915 , Accuracy : 77.5
# Training model to test on subject 09 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.70000, saving model to ../saved_models/best_model_for_s09_valence(2classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.70000 to 0.77500, saving model to ../saved_models/best_model_for_s09_valence(2classes).h5
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 181us/step
# #### Result of DNN model for subject 09 #####
#
# Loss: 0.564231586456 , Accuracy : 77.5
# Training model to test on subject 10 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.72500, saving model to ../saved_models/best_model_for_s10_valence(2classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.72500 to 0.80000, saving model to ../saved_models/best_model_for_s10_valence(2classes).h5
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy improved from 0.80000 to 0.82500, saving model to ../saved_models/best_model_for_s10_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 180us/step
# #### Result of DNN model for subject 10 #####
#
# Loss: 0.480399107933 , Accuracy : 82.5
# Training model to test on subject 11 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.42500, saving model to ../saved_models/best_model_for_s11_valence(2classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.42500 to 0.50000, saving model to ../saved_models/best_model_for_s11_valence(2classes).h5
# Epoch 00060: val_categorical_accuracy improved from 0.50000 to 0.57500, saving model to ../saved_models/best_model_for_s11_valence(2classes).h5
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy improved from 0.57500 to 0.60000, saving model to ../saved_models/best_model_for_s11_valence(2classes).h5
# Epoch 00140: val_categorical_accuracy improved from 0.60000 to 0.62500, saving model to ../saved_models/best_model_for_s11_valence(2classes).h5
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy improved from 0.62500 to 0.65000, saving model to ../saved_models/best_model_for_s11_valence(2classes).h5
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 175us/step
# #### Result of DNN model for subject 11 #####
#
# Loss: 0.763751858473 , Accuracy : 65.0
# Training model to test on subject 12 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.67500, saving model to ../saved_models/best_model_for_s12_valence(2classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.67500 to 0.77500, saving model to ../saved_models/best_model_for_s12_valence(2classes).h5
# Epoch 00060: val_categorical_accuracy improved from 0.77500 to 0.82500, saving model to ../saved_models/best_model_for_s12_valence(2classes).h5
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy improved from 0.82500 to 0.85000, saving model to ../saved_models/best_model_for_s12_valence(2classes).h5
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 183us/step
# #### Result of DNN model for subject 12 #####
#
# Loss: 0.568833804131 , Accuracy : 85.0
# Training model to test on subject 13 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.67500, saving model to ../saved_models/best_model_for_s13_valence(2classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.67500 to 0.72500, saving model to ../saved_models/best_model_for_s13_valence(2classes).h5
# Epoch 00060: val_categorical_accuracy improved from 0.72500 to 0.75000, saving model to ../saved_models/best_model_for_s13_valence(2classes).h5
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy improved from 0.75000 to 0.77500, saving model to ../saved_models/best_model_for_s13_valence(2classes).h5
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 179us/step
# #### Result of DNN model for subject 13 #####
#
# Loss: 0.535863187909 , Accuracy : 77.5
# Training model to test on subject 14 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.85000, saving model to ../saved_models/best_model_for_s14_valence(2classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 176us/step
# #### Result of DNN model for subject 14 #####
#
# Loss: 0.568196475506 , Accuracy : 85.0
# Training model to test on subject 15 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.82500, saving model to ../saved_models/best_model_for_s15_valence(2classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.82500 to 0.85000, saving model to ../saved_models/best_model_for_s15_valence(2classes).h5
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 183us/step
# #### Result of DNN model for subject 15 #####
#
# Loss: 0.472646296024 , Accuracy : 85.0
# Training model to test on subject 16 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.45000, saving model to ../saved_models/best_model_for_s16_valence(2classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.45000 to 0.47500, saving model to ../saved_models/best_model_for_s16_valence(2classes).h5
# Epoch 00060: val_categorical_accuracy improved from 0.47500 to 0.50000, saving model to ../saved_models/best_model_for_s16_valence(2classes).h5
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy improved from 0.50000 to 0.52500, saving model to ../saved_models/best_model_for_s16_valence(2classes).h5
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 180us/step
# #### Result of DNN model for subject 16 #####
#
# Loss: 1.02789560556 , Accuracy : 52.5
# Training model to test on subject 17 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.75000, saving model to ../saved_models/best_model_for_s17_valence(2classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.75000 to 0.77500, saving model to ../saved_models/best_model_for_s17_valence(2classes).h5
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy improved from 0.77500 to 0.80000, saving model to ../saved_models/best_model_for_s17_valence(2classes).h5
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 174us/step
# #### Result of DNN model for subject 17 #####
#
# Loss: 0.559603619576 , Accuracy : 80.0
# Training model to test on subject 18 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.72500, saving model to ../saved_models/best_model_for_s18_valence(2classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.72500 to 0.80000, saving model to ../saved_models/best_model_for_s18_valence(2classes).h5
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy improved from 0.80000 to 0.82500, saving model to ../saved_models/best_model_for_s18_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 182us/step
# #### Result of DNN model for subject 18 #####
#
# Loss: 0.477421319485 , Accuracy : 82.5
# Training model to test on subject 19 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.77500, saving model to ../saved_models/best_model_for_s19_valence(2classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.77500 to 0.82500, saving model to ../saved_models/best_model_for_s19_valence(2classes).h5
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 178us/step
# #### Result of DNN model for subject 19 #####
#
# Loss: 0.507573312521 , Accuracy : 82.5
# Training model to test on subject 20 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.87500, saving model to ../saved_models/best_model_for_s20_valence(2classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.87500 to 0.90000, saving model to ../saved_models/best_model_for_s20_valence(2classes).h5
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 207us/step
# #### Result of DNN model for subject 20 #####
#
# Loss: 0.425922256708 , Accuracy : 90.0
# Training model to test on subject 21 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.67500, saving model to ../saved_models/best_model_for_s21_valence(2classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy improved from 0.67500 to 0.70000, saving model to ../saved_models/best_model_for_s21_valence(2classes).h5
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy improved from 0.70000 to 0.72500, saving model to ../saved_models/best_model_for_s21_valence(2classes).h5
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy improved from 0.72500 to 0.75000, saving model to ../saved_models/best_model_for_s21_valence(2classes).h5
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 202us/step
# #### Result of DNN model for subject 21 #####
#
# Loss: 0.628162872791 , Accuracy : 75.0
# Training model to test on subject 22 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.77500, saving model to ../saved_models/best_model_for_s22_valence(2classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy improved from 0.77500 to 0.80000, saving model to ../saved_models/best_model_for_s22_valence(2classes).h5
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy improved from 0.80000 to 0.82500, saving model to ../saved_models/best_model_for_s22_valence(2classes).h5
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 185us/step
# #### Result of DNN model for subject 22 #####
#
# Loss: 0.589183759689 , Accuracy : 82.5
# Training model to test on subject 23 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.67500, saving model to ../saved_models/best_model_for_s23_valence(2classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy improved from 0.67500 to 0.70000, saving model to ../saved_models/best_model_for_s23_valence(2classes).h5
# Epoch 00080: val_categorical_accuracy improved from 0.70000 to 0.72500, saving model to ../saved_models/best_model_for_s23_valence(2classes).h5
# Epoch 00100: val_categorical_accuracy improved from 0.72500 to 0.75000, saving model to ../saved_models/best_model_for_s23_valence(2classes).h5
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 189us/step
# #### Result of DNN model for subject 23 #####
#
# Loss: 0.54087959528 , Accuracy : 75.0
# Training model to test on subject 24 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.62500, saving model to ../saved_models/best_model_for_s24_valence(2classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.62500 to 0.77500, saving model to ../saved_models/best_model_for_s24_valence(2classes).h5
# Epoch 00060: val_categorical_accuracy improved from 0.77500 to 0.85000, saving model to ../saved_models/best_model_for_s24_valence(2classes).h5
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 210us/step
# #### Result of DNN model for subject 24 #####
#
# Loss: 0.54453420043 , Accuracy : 85.0
# Training model to test on subject 25 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.70000, saving model to ../saved_models/best_model_for_s25_valence(2classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy improved from 0.70000 to 0.72500, saving model to ../saved_models/best_model_for_s25_valence(2classes).h5
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy improved from 0.72500 to 0.75000, saving model to ../saved_models/best_model_for_s25_valence(2classes).h5
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 212us/step
# #### Result of DNN model for subject 25 #####
#
# Loss: 0.644261872768 , Accuracy : 75.0
# Training model to test on subject 26 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.60000, saving model to ../saved_models/best_model_for_s26_valence(2classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.60000 to 0.67500, saving model to ../saved_models/best_model_for_s26_valence(2classes).h5
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 196us/step
# #### Result of DNN model for subject 26 #####
#
# Loss: 0.602187359333 , Accuracy : 67.5
# Training model to test on subject 27 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.57500, saving model to ../saved_models/best_model_for_s27_valence(2classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy improved from 0.57500 to 0.60000, saving model to ../saved_models/best_model_for_s27_valence(2classes).h5
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 196us/step
# #### Result of DNN model for subject 27 #####
#
# Loss: 0.708026814461 , Accuracy : 60.0
# Training model to test on subject 28 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.67500, saving model to ../saved_models/best_model_for_s28_valence(2classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.67500 to 0.77500, saving model to ../saved_models/best_model_for_s28_valence(2classes).h5
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy improved from 0.77500 to 0.80000, saving model to ../saved_models/best_model_for_s28_valence(2classes).h5
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 203us/step
# #### Result of DNN model for subject 28 #####
#
# Loss: 0.489710831642 , Accuracy : 80.0
# Training model to test on subject 29 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.65000, saving model to ../saved_models/best_model_for_s29_valence(2classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.65000 to 0.75000, saving model to ../saved_models/best_model_for_s29_valence(2classes).h5
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 185us/step
# #### Result of DNN model for subject 29 #####
#
# Loss: 0.539594435692 , Accuracy : 75.0
# Training model to test on subject 30 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.57500, saving model to ../saved_models/best_model_for_s30_valence(2classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.57500 to 0.67500, saving model to ../saved_models/best_model_for_s30_valence(2classes).h5
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy improved from 0.67500 to 0.70000, saving model to ../saved_models/best_model_for_s30_valence(2classes).h5
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy improved from 0.70000 to 0.72500, saving model to ../saved_models/best_model_for_s30_valence(2classes).h5
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 186us/step
# #### Result of DNN model for subject 30 #####
#
# Loss: 0.613261318207 , Accuracy : 72.5
# Training model to test on subject 31 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.75000, saving model to ../saved_models/best_model_for_s31_valence(2classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.75000 to 0.80000, saving model to ../saved_models/best_model_for_s31_valence(2classes).h5
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 186us/step
# #### Result of DNN model for subject 31 #####
#
# Loss: 0.524349582195 , Accuracy : 80.0
# Training model to test on subject 32 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.70000, saving model to ../saved_models/best_model_for_s32_valence(2classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.70000 to 0.72500, saving model to ../saved_models/best_model_for_s32_valence(2classes).h5
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy improved from 0.72500 to 0.75000, saving model to ../saved_models/best_model_for_s32_valence(2classes).h5
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 182us/step
# #### Result of DNN model for subject 32 #####
#
# Loss: 0.602243590355 , Accuracy : 75.0

# %%
print np.argmin(accuracies), np.argmax(accuracies)
print reduce(lambda x, y: x + y, accuracies) / len(accuracies)
accuracies
# Out:
# 15 19
# 0.76171875
# [0.72499999999999998,
#  0.82499999999999996,
#  0.72499999999999998,
#  0.69999999999999996,
#  0.69999999999999996,
#  0.72499999999999998,
#  0.72499999999999998,
#  0.77500000000000002,
#  0.77500000000000002,
#  0.82499999999999996,
#  0.65000000000000002,
#  0.84999999999999998,
#  0.77500000000000002,
#  0.84999999999999998,
#  0.84999999999999998,
#  0.52500000000000002,
#  0.80000000000000004,
#  0.82499999999999996,
#  0.82499999999999996,
#  0.90000000000000002,
#  0.75,
#  0.82499999999999996,
#  0.75,
#  0.84999999999999998,
#  0.75,
#  0.67500000000000004,
#  0.59999999999999998,
#  0.80000000000000004,
#  0.75,
#  0.72499999999999998,
#  0.80000000000000004,
#  0.75]

# %% [markdown]
# # Load data for three classes classification

# %% [markdown]
# # Train CNN model for two classes (low Valence / High Valence) classification

# %%
batch_size = 50

epochs = 250
num_subjects = 32

for s in np.arange(0, num_subjects):
    
    
    X_val = reduced_data_folds[s]
    X_val = X_val.reshape(X_val.shape[0], 1, 40, 101)
    y_val = valence_folds[s]
    
    X_remaining_folds = reduced_data_folds[:s] + reduced_data_folds[s+1:]
    y_remaining_folds = valence_folds[:s] + valence_folds[s+1:]
    
    X_train = np.concatenate(X_remaining_folds)
    X_train = X_train.reshape(X_train.shape[0], 1, 40, 101)
    
    y_train = np.concatenate(y_remaining_folds)
    
    
    # Valence classification model for two classes    
    model_valence_2class = nn.CNN(num_classes=2)
    hist = model_valence_2class.fit(X_train, y_train, 
             batch_size=batch_size,
             epochs=epochs,
             shuffle=True,
             verbose=0,
             validation_data=(X_val, y_val))

    #print hist.history

    # summarize history for accuracy
    plt.plot(hist.history['categorical_accuracy'])
    plt.plot(hist.history['val_categorical_accuracy'])
    plt.title('Subject ' +str(s).zfill(2)+ ' DNN model accuracy for Valence')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-07a8013b2eb8> in <module>()
#      27              shuffle=True,
#      28              verbose=0,
# ---> 29              validation_data=(X_val, y_val))
#      30
#      31     #print hist.history
#
# /home/omid/venv2/local/lib/python2.7/site-packages/Keras-2.1.2-py2.7.egg/keras/models.pyc in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#     958                               initial_epoch=initial_epoch,
#     959                               steps_per_epoch=steps_per_epoch,
# --> 960                               validation_steps=validation_steps)
#     961
#     962     def evaluate(self, x, y, batch_size=None, verbose=1,
#
# /home/omid/venv2/local/lib/python2.7/site-packages/Keras-2.1.2-py2.7.egg/keras/engine/training.pyc in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1655                               initial_epoch=initial_epoch,
#    1656                               steps_per_epoch=steps_per_epoch,
# -> 1657                               validation_steps=validation_steps)
#    1658
#    1659     def evaluate(self, x=None, y=None,
#
# /home/omid/venv2/local/lib/python2.7/site-packages/Keras-2.1.2-py2.7.egg/keras/engine/training.pyc in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1211                     batch_logs['size'] = len(batch_ids)
#    1212                     callbacks.on_batch_begin(batch_index, batch_logs)
# -> 1213                     outs = f(ins_batch)
#    1214                     if not isinstance(outs, list):
#    1215                         outs = [outs]
#
# /home/omid/venv2/local/lib/python2.7/site-packages/Keras-2.1.2-py2.7.egg/keras/backend/tensorflow_backend.pyc in __call__(self, inputs)
#    2363         session = get_session()
#    2364         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2365                               **self.session_kwargs)
#    2366         return updated[:len(self.outputs)]
#    2367
#
# /home/omid/venv2/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/omid/venv2/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# /home/omid/venv2/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /home/omid/venv2/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1321   def _do_call(self, fn, *args):
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#    1325       message = compat.as_text(e.message)
#
# /home/omid/venv2/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1300           return tf_session.TF_Run(session, options,
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#    1304     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
