# %% [markdown]
# # Import Libraries

# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt
import time
import pickle
from sklearn.preprocessing import scale
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard
from keras.models import load_model
from keras import metrics
from keras.regularizers import l2
import models.nnmodels as nn
import utils.data as data

import gc
gc.enable()
seed = 0
np.random.seed(seed)
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Load DEAP pre-processed data

# %%
print 'Loading DEAP dataset...'
subject_data_folds, valence_folds, arousal_folds = data.load_deap(32, 2)
print 'DEAP dataset is loaded.\n'

print 5*'#' + ' Dataset representation for each subject ' + 5*'#'
print '\nThere are {} subjects in the dataset.\n'.format(len(subject_data_folds))
print '(Trail/Video, Channel, Readings) : ', subject_data_folds[0].shape
print '(Trail/Video, label (valence or arousal)) : ', arousal_folds[0].shape
# Out:
# Loading DEAP dataset...
# DEAP dataset is loaded.
#
# ##### Dataset representation for each subject #####
#
# There are 32 subjects in the dataset.
#
# (Trail/Video, Channel, Readings) :  (40, 40, 8064)
# (Trail/Video, label (valence or arousal)) :  (40, 2)

# %% [markdown]
# # Select the channels which have significant correlation

# %% [raw]
# # Create a boolean mask to select specific channels
# # mask to select channels 1, 2, 4, 5, 8, 10, 15, 21, 22, 25, 26, 27, 28, 31, 32
# mask = [True, True, False, True, True, False, False, True, False, True, False, False, False, False, True, \
#        False, False, False, False, False, True, True, False, False, True, True, True, True, False, False, \
#        True, True, False, False, False, False, False, False, False, False]
#
# subject_data_folds_15ch = []
# for s in subject_data_folds:
#     subject_data_folds_15ch.append(s[:,mask,:])
#
# # Check the shape
# subject_data_folds_15ch[0].shape

# %% [markdown]
# # Normalize

# %%
# Concatenate the data
X = np.concatenate(subject_data_folds)
# Reshape
(trials, channels, readings) = X.shape
X_reshaped = X.reshape(trials, channels*readings)

# Normalize
X_reshaped_normalized = scale(X_reshaped)

X_normalized =  X_reshaped_normalized.reshape(trials, channels, readings)

Normalized_data = np.split(X_normalized, 32)

# %%
# Split each sample into 10 sample (400 experiment per subject) 


# Select last 30 seconds of only EGG channels
first_4_readings_removed = []
for fold in Normalized_data:
    first_4_readings_removed.append(fold[:,:,4:])
    
# Sanity check the shape 
print ('Shape of each subject data: {}'.format(first_4_readings_removed[0].shape))

augmented_data_folds = []
for fold in first_4_readings_removed:
    
    subject_splited = np.split(fold, 10, axis=-1)
    augmented_subject = np.concatenate(subject_splited)
    
    augmented_data_folds.append(augmented_subject)

# Produce the labels for segments
augmented_valence_labels = []
for l in valence_folds:
    new_l = l.repeat(10, axis=0)
    augmented_valence_labels.append(new_l)

# Sanity check the shape of subject and labels
print ('Augmented subject has the shape of {}'.format(augmented_data_folds[0].shape))
print ('Augmented valence labels has the shape of {}'.format(augmented_valence_labels[0].shape))
# Out:
# Shape of each subject data: (40, 40, 8060)
# Augmented subject has the shape of (400, 40, 806)
# Augmented valence labels has the shape of (400, 2)

# %% [markdown]
# # Reduce dimension

# %%
# Reduce the features dimension
print 'Mapping features into Gaussian with mean zero and unit variance...'
Normalized_data_reduced = data.normalize_features(augmented_data_folds, pre_norm=False)
print 'Normalization done.'
# Out:
# Mapping features into Gaussian with mean zero and unit variance...
# Normalization done.

# %% [markdown]
# # Save the processed data into pickles for later uses

# %%
with open('../pickles/Normalized_data_reduced.pickle', 'wb') as handle:
    pickle.dump(Normalized_data_reduced, handle, protocol=pickle.HIGHEST_PROTOCOL)

with open('../pickles/augmented_valence_labels.pickle', 'wb') as handle:
    pickle.dump(augmented_valence_labels, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# # Start from the following cell to if you have the pickles of processed data

# %%
    
# import libraries
import numpy as np
import matplotlib.pyplot as plt
import time
import pickle
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard
from keras.models import load_model
from keras import metrics
from sklearn.preprocessing import scale
from keras.regularizers import l2
import models.nnmodels as nn
import utils.data as data

import gc
gc.enable()
seed = 0
np.random.seed(seed)
# %matplotlib inline



with open('../pickles/Normalized_data_reduced.pickle', 'rb') as handle:
    Normalized_data_reduced = pickle.load(handle)
    
with open('../pickles/augmented_valence_labels.pickle', 'rb') as handle:
    augmented_valence_labels = pickle.load(handle)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Training the Classification Model

# %%
um_exp = 40
num_classes = 2
batch_size = 50
epochs = 50
num_subjects = 32


accuracies= []

print '##### Two Classes Classification for Valence emotion Using Convolutional Neural Network #####\n'
   

for s in np.arange(0, num_subjects):
    
    
    X_val = Normalized_data_reduced[s]
    X_val = np.expand_dims(X_val, axis=1)
    y_val = augmented_valence_labels[s]
    
    X_remaining_folds = Normalized_data_reduced[:s] + Normalized_data_reduced[s+1:]
    y_remaining_folds = augmented_valence_labels[:s] + augmented_valence_labels[s+1:]
    
    X_train = np.concatenate(X_remaining_folds)
    X_train = np.expand_dims(X_train, axis=1)
    
    y_train = np.concatenate(y_remaining_folds)
    
    # To test major vote predictions at the end
    #y_test = valence_folds[s]
    
    
    key = 's'+str(s+1).zfill(2)+'_valence(2classes)'
    
    
    # Valence classification model for two classes    
    model = nn.CNN(num_classes=num_classes, emotion='valence', input_shape=X_train.shape[1:])
    
    
    # checkpoint
    filepath="../saved_models/best_CNN_model_for_{}.h5".format(key)
    
    print 'Training model to test on subject {} ...\n'.format(str(s+1).zfill(2))
    
    checkpoint = ModelCheckpoint(filepath, monitor='val_categorical_accuracy',
                                verbose=1, save_best_only=True, mode='max', period=1)
    
    callbacks_list = [checkpoint]
    
    
    hist = model.fit(X_train, y_train, 
             batch_size=batch_size,
             epochs=epochs,
             shuffle=True,
             verbose=0,
             validation_data=(X_val, y_val), callbacks=callbacks_list)

    model.load_weights(filepath)
    
    scores = model.evaluate(x=X_val, y=y_val)
    
    
    """
    

    
    y_val_pred = model.predict(X_val)
    
    pred_list = np.split(y_val_pred, 40)
    
    y_test_pred_list = []
    for pred in pred_list:
        
        class_zero = np.sum(pred[:,0])
        class_one = np.sum(pred[:,1])
        
        if class_zero >class_one:
            y_test_pred_list.append(np.array([[1,0]]))
        elif class_zero <= class_one:
            y_test_pred_list.append(np.array([[1,0]]))
            
    y_test_pred = np.concatenate(y_test_pred_list)
    
    truth_table = y_test_pred == y_test
        
    acc = 100*np.sum(truth_table)/len(truth_table)
        
     """
    
    
    
    print '#### Result of CNN model for subject {} #####\n'.format(str(s+1).zfill(2))
    print "Validation Loss: {} , Validation Accuracy : {}%".format(scores[0], scores[1]*100)
    
    #print 'Major voting accuracy is: {}%'.format(acc)
    
    

    accuracies.append(scores[1])
    # summarize history for accuracy
    plt.plot(hist.history['categorical_accuracy'])
    plt.plot(hist.history['val_categorical_accuracy'])
    plt.title('Subject ' +str(s+1).zfill(2)+ ' CNN model accuracy for Valence')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    
    
    # summarize history for loss
    plt.plot(hist.history['loss'])
    plt.plot(hist.history['val_loss'])
    plt.title('Subject ' +str(s+1).zfill(2) + ' CNN model loss for Valence')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

    del model
# Out:
# ##### Two Classes Classification for Valence emotion Using Convolutional Neural Network #####
#
# Training model to test on subject 01 ...
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.47500, saving model to ../saved_models/best_CNN_model_for_s01_valence(2classes).h5
# Epoch 00002: val_categorical_accuracy improved from 0.47500 to 0.51500, saving model to ../saved_models/best_CNN_model_for_s01_valence(2classes).h5
# Epoch 00003: val_categorical_accuracy improved from 0.51500 to 0.61500, saving model to ../saved_models/best_CNN_model_for_s01_valence(2classes).h5
# Epoch 00004: val_categorical_accuracy improved from 0.61500 to 0.68250, saving model to ../saved_models/best_CNN_model_for_s01_valence(2classes).h5
# Epoch 00005: val_categorical_accuracy improved from 0.68250 to 0.73250, saving model to ../saved_models/best_CNN_model_for_s01_valence(2classes).h5
# Epoch 00006: val_categorical_accuracy improved from 0.73250 to 0.73750, saving model to ../saved_models/best_CNN_model_for_s01_valence(2classes).h5
# Epoch 00007: val_categorical_accuracy did not improve
# Epoch 00008: val_categorical_accuracy did not improve
# Epoch 00009: val_categorical_accuracy did not improve
# Epoch 00010: val_categorical_accuracy did not improve
# Epoch 00011: val_categorical_accuracy did not improve
# Epoch 00012: val_categorical_accuracy did not improve
# Epoch 00013: val_categorical_accuracy did not improve
# Epoch 00014: val_categorical_accuracy did not improve
# Epoch 00015: val_categorical_accuracy did not improve
# Epoch 00016: val_categorical_accuracy did not improve
# Epoch 00017: val_categorical_accuracy did not improve
# Epoch 00018: val_categorical_accuracy did not improve
# Epoch 00019: val_categorical_accuracy did not improve
# Epoch 00020: val_categorical_accuracy did not improve
# Epoch 00021: val_categorical_accuracy did not improve
# Epoch 00022: val_categorical_accuracy did not improve
# Epoch 00023: val_categorical_accuracy did not improve
# Epoch 00024: val_categorical_accuracy did not improve
# Epoch 00025: val_categorical_accuracy did not improve
# Epoch 00026: val_categorical_accuracy did not improve
# Epoch 00027: val_categorical_accuracy did not improve
# Epoch 00028: val_categorical_accuracy did not improve
# Epoch 00029: val_categorical_accuracy did not improve
# Epoch 00030: val_categorical_accuracy did not improve
# Epoch 00031: val_categorical_accuracy did not improve
# Epoch 00032: val_categorical_accuracy did not improve
# Epoch 00033: val_categorical_accuracy did not improve
# Epoch 00034: val_categorical_accuracy did not improve
# Epoch 00035: val_categorical_accuracy did not improve
# Epoch 00036: val_categorical_accuracy did not improve
# Epoch 00037: val_categorical_accuracy did not improve
# Epoch 00038: val_categorical_accuracy did not improve
# Epoch 00039: val_categorical_accuracy did not improve
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00041: val_categorical_accuracy did not improve
# Epoch 00042: val_categorical_accuracy did not improve
# Epoch 00043: val_categorical_accuracy did not improve
# Epoch 00044: val_categorical_accuracy did not improve
# Epoch 00045: val_categorical_accuracy did not improve
# Epoch 00046: val_categorical_accuracy did not improve
# Epoch 00047: val_categorical_accuracy did not improve
# Epoch 00048: val_categorical_accuracy did not improve
# Epoch 00049: val_categorical_accuracy did not improve
# Epoch 00050: val_categorical_accuracy did not improve
# 400/400 [==============================] - 0s 796us/step
# #### Result of CNN model for subject 01 #####
#
# Validation Loss: 0.657789702415 , Validation Accuracy : 73.75%
# Training model to test on subject 02 ...
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.56000, saving model to ../saved_models/best_CNN_model_for_s02_valence(2classes).h5
# Epoch 00002: val_categorical_accuracy improved from 0.56000 to 0.68750, saving model to ../saved_models/best_CNN_model_for_s02_valence(2classes).h5
# Epoch 00003: val_categorical_accuracy did not improve
# Epoch 00004: val_categorical_accuracy improved from 0.68750 to 0.73000, saving model to ../saved_models/best_CNN_model_for_s02_valence(2classes).h5
# Epoch 00005: val_categorical_accuracy improved from 0.73000 to 0.74000, saving model to ../saved_models/best_CNN_model_for_s02_valence(2classes).h5
# Epoch 00006: val_categorical_accuracy improved from 0.74000 to 0.74250, saving model to ../saved_models/best_CNN_model_for_s02_valence(2classes).h5
# Epoch 00007: val_categorical_accuracy improved from 0.74250 to 0.74500, saving model to ../saved_models/best_CNN_model_for_s02_valence(2classes).h5
# Epoch 00008: val_categorical_accuracy improved from 0.74500 to 0.74750, saving model to ../saved_models/best_CNN_model_for_s02_valence(2classes).h5
# Epoch 00009: val_categorical_accuracy improved from 0.74750 to 0.74750, saving model to ../saved_models/best_CNN_model_for_s02_valence(2classes).h5
# Epoch 00010: val_categorical_accuracy improved from 0.74750 to 0.75750, saving model to ../saved_models/best_CNN_model_for_s02_valence(2classes).h5
# Epoch 00011: val_categorical_accuracy did not improve
# Epoch 00012: val_categorical_accuracy improved from 0.75750 to 0.76000, saving model to ../saved_models/best_CNN_model_for_s02_valence(2classes).h5
# Epoch 00013: val_categorical_accuracy did not improve
# Epoch 00014: val_categorical_accuracy improved from 0.76000 to 0.76500, saving model to ../saved_models/best_CNN_model_for_s02_valence(2classes).h5
# Epoch 00015: val_categorical_accuracy improved from 0.76500 to 0.76500, saving model to ../saved_models/best_CNN_model_for_s02_valence(2classes).h5
# Epoch 00016: val_categorical_accuracy improved from 0.76500 to 0.76750, saving model to ../saved_models/best_CNN_model_for_s02_valence(2classes).h5
# Epoch 00017: val_categorical_accuracy did not improve
# Epoch 00018: val_categorical_accuracy did not improve
# Epoch 00019: val_categorical_accuracy improved from 0.76750 to 0.77000, saving model to ../saved_models/best_CNN_model_for_s02_valence(2classes).h5
# Epoch 00020: val_categorical_accuracy did not improve
# Epoch 00021: val_categorical_accuracy did not improve
# Epoch 00022: val_categorical_accuracy did not improve
# Epoch 00023: val_categorical_accuracy did not improve
# Epoch 00024: val_categorical_accuracy did not improve
# Epoch 00025: val_categorical_accuracy did not improve
# Epoch 00026: val_categorical_accuracy improved from 0.77000 to 0.77000, saving model to ../saved_models/best_CNN_model_for_s02_valence(2classes).h5
# Epoch 00027: val_categorical_accuracy improved from 0.77000 to 0.78000, saving model to ../saved_models/best_CNN_model_for_s02_valence(2classes).h5
# Epoch 00028: val_categorical_accuracy did not improve
# Epoch 00029: val_categorical_accuracy did not improve
# Epoch 00030: val_categorical_accuracy did not improve
# Epoch 00031: val_categorical_accuracy did not improve
# Epoch 00032: val_categorical_accuracy did not improve
# Epoch 00033: val_categorical_accuracy did not improve
# Epoch 00034: val_categorical_accuracy did not improve
# Epoch 00035: val_categorical_accuracy did not improve
# Epoch 00036: val_categorical_accuracy did not improve
# Epoch 00037: val_categorical_accuracy did not improve
# Epoch 00038: val_categorical_accuracy did not improve
# Epoch 00039: val_categorical_accuracy did not improve
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00041: val_categorical_accuracy did not improve
# Epoch 00042: val_categorical_accuracy did not improve
# Epoch 00043: val_categorical_accuracy did not improve
# Epoch 00044: val_categorical_accuracy did not improve
# Epoch 00045: val_categorical_accuracy did not improve
# Epoch 00046: val_categorical_accuracy did not improve
# Epoch 00047: val_categorical_accuracy did not improve
# Epoch 00048: val_categorical_accuracy did not improve
# Epoch 00049: val_categorical_accuracy did not improve
# Epoch 00050: val_categorical_accuracy did not improve
# 400/400 [==============================] - 0s 497us/step
# #### Result of CNN model for subject 02 #####
#
# Validation Loss: 0.558525780439 , Validation Accuracy : 78.0%
# Training model to test on subject 03 ...
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.67500, saving model to ../saved_models/best_CNN_model_for_s03_valence(2classes).h5
# Epoch 00002: val_categorical_accuracy improved from 0.67500 to 0.70000, saving model to ../saved_models/best_CNN_model_for_s03_valence(2classes).h5
# Epoch 00003: val_categorical_accuracy improved from 0.70000 to 0.72000, saving model to ../saved_models/best_CNN_model_for_s03_valence(2classes).h5
# Epoch 00004: val_categorical_accuracy improved from 0.72000 to 0.73500, saving model to ../saved_models/best_CNN_model_for_s03_valence(2classes).h5
# Epoch 00005: val_categorical_accuracy improved from 0.73500 to 0.74000, saving model to ../saved_models/best_CNN_model_for_s03_valence(2classes).h5
# Epoch 00006: val_categorical_accuracy did not improve
# Epoch 00007: val_categorical_accuracy improved from 0.74000 to 0.75750, saving model to ../saved_models/best_CNN_model_for_s03_valence(2classes).h5
# Epoch 00008: val_categorical_accuracy did not improve
# Epoch 00009: val_categorical_accuracy did not improve
# Epoch 00010: val_categorical_accuracy improved from 0.75750 to 0.76000, saving model to ../saved_models/best_CNN_model_for_s03_valence(2classes).h5
# Epoch 00011: val_categorical_accuracy did not improve
# Epoch 00012: val_categorical_accuracy did not improve
# Epoch 00013: val_categorical_accuracy did not improve
# Epoch 00014: val_categorical_accuracy did not improve
# Epoch 00015: val_categorical_accuracy did not improve
# Epoch 00016: val_categorical_accuracy did not improve
# Epoch 00017: val_categorical_accuracy did not improve
# Epoch 00018: val_categorical_accuracy did not improve
# Epoch 00019: val_categorical_accuracy did not improve
# Epoch 00020: val_categorical_accuracy did not improve
# Epoch 00021: val_categorical_accuracy did not improve
# Epoch 00022: val_categorical_accuracy did not improve
# Epoch 00023: val_categorical_accuracy did not improve
# Epoch 00024: val_categorical_accuracy did not improve
# Epoch 00025: val_categorical_accuracy did not improve
# Epoch 00026: val_categorical_accuracy did not improve
# Epoch 00027: val_categorical_accuracy did not improve
# Epoch 00028: val_categorical_accuracy did not improve
# Epoch 00029: val_categorical_accuracy did not improve
# Epoch 00030: val_categorical_accuracy did not improve
# Epoch 00031: val_categorical_accuracy did not improve
# Epoch 00032: val_categorical_accuracy did not improve
# Epoch 00033: val_categorical_accuracy did not improve
# Epoch 00034: val_categorical_accuracy did not improve
# Epoch 00035: val_categorical_accuracy did not improve
# Epoch 00036: val_categorical_accuracy did not improve
# Epoch 00037: val_categorical_accuracy did not improve
# Epoch 00038: val_categorical_accuracy did not improve
# Epoch 00039: val_categorical_accuracy did not improve
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00041: val_categorical_accuracy did not improve
# Epoch 00042: val_categorical_accuracy did not improve
# Epoch 00043: val_categorical_accuracy did not improve
# Epoch 00044: val_categorical_accuracy did not improve
# Epoch 00045: val_categorical_accuracy did not improve
# Epoch 00046: val_categorical_accuracy did not improve
# Epoch 00047: val_categorical_accuracy did not improve
# Epoch 00048: val_categorical_accuracy did not improve
# Epoch 00049: val_categorical_accuracy did not improve
# Epoch 00050: val_categorical_accuracy did not improve
# 400/400 [==============================] - 0s 502us/step
# #### Result of CNN model for subject 03 #####
#
# Validation Loss: 0.575534613132 , Validation Accuracy : 76.0%
# Training model to test on subject 04 ...
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.44000, saving model to ../saved_models/best_CNN_model_for_s04_valence(2classes).h5
# Epoch 00002: val_categorical_accuracy improved from 0.44000 to 0.45000, saving model to ../saved_models/best_CNN_model_for_s04_valence(2classes).h5
# Epoch 00003: val_categorical_accuracy improved from 0.45000 to 0.60250, saving model to ../saved_models/best_CNN_model_for_s04_valence(2classes).h5
# Epoch 00004: val_categorical_accuracy improved from 0.60250 to 0.65750, saving model to ../saved_models/best_CNN_model_for_s04_valence(2classes).h5
# Epoch 00005: val_categorical_accuracy improved from 0.65750 to 0.67750, saving model to ../saved_models/best_CNN_model_for_s04_valence(2classes).h5
# Epoch 00006: val_categorical_accuracy did not improve
# Epoch 00007: val_categorical_accuracy improved from 0.67750 to 0.69500, saving model to ../saved_models/best_CNN_model_for_s04_valence(2classes).h5
# Epoch 00008: val_categorical_accuracy did not improve
# Epoch 00009: val_categorical_accuracy improved from 0.69500 to 0.70750, saving model to ../saved_models/best_CNN_model_for_s04_valence(2classes).h5
# Epoch 00010: val_categorical_accuracy did not improve
# Epoch 00011: val_categorical_accuracy improved from 0.70750 to 0.71250, saving model to ../saved_models/best_CNN_model_for_s04_valence(2classes).h5
# Epoch 00012: val_categorical_accuracy did not improve
# Epoch 00013: val_categorical_accuracy did not improve
# Epoch 00014: val_categorical_accuracy did not improve
# Epoch 00015: val_categorical_accuracy did not improve
# Epoch 00016: val_categorical_accuracy did not improve
# Epoch 00017: val_categorical_accuracy did not improve
# Epoch 00018: val_categorical_accuracy improved from 0.71250 to 0.71750, saving model to ../saved_models/best_CNN_model_for_s04_valence(2classes).h5
# Epoch 00019: val_categorical_accuracy did not improve
# Epoch 00020: val_categorical_accuracy did not improve
# Epoch 00021: val_categorical_accuracy did not improve
# Epoch 00022: val_categorical_accuracy did not improve
# Epoch 00023: val_categorical_accuracy did not improve
# Epoch 00024: val_categorical_accuracy did not improve
# Epoch 00025: val_categorical_accuracy did not improve
# Epoch 00026: val_categorical_accuracy did not improve
# Epoch 00027: val_categorical_accuracy did not improve
# Epoch 00028: val_categorical_accuracy did not improve
# Epoch 00029: val_categorical_accuracy did not improve
# Epoch 00030: val_categorical_accuracy did not improve
# Epoch 00031: val_categorical_accuracy improved from 0.71750 to 0.72000, saving model to ../saved_models/best_CNN_model_for_s04_valence(2classes).h5
# Epoch 00032: val_categorical_accuracy did not improve
# Epoch 00033: val_categorical_accuracy did not improve
# Epoch 00034: val_categorical_accuracy did not improve
# Epoch 00035: val_categorical_accuracy did not improve
# Epoch 00036: val_categorical_accuracy did not improve
# Epoch 00037: val_categorical_accuracy did not improve
# Epoch 00038: val_categorical_accuracy did not improve
# Epoch 00039: val_categorical_accuracy did not improve
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00041: val_categorical_accuracy did not improve
# Epoch 00042: val_categorical_accuracy did not improve
# Epoch 00043: val_categorical_accuracy did not improve
# Epoch 00044: val_categorical_accuracy did not improve
# Epoch 00045: val_categorical_accuracy did not improve
# Epoch 00046: val_categorical_accuracy improved from 0.72000 to 0.72250, saving model to ../saved_models/best_CNN_model_for_s04_valence(2classes).h5
# Epoch 00047: val_categorical_accuracy did not improve
# Epoch 00048: val_categorical_accuracy did not improve
# Epoch 00049: val_categorical_accuracy did not improve
# Epoch 00050: val_categorical_accuracy did not improve
# 400/400 [==============================] - 0s 495us/step
# #### Result of CNN model for subject 04 #####
#
# Validation Loss: 0.574805935621 , Validation Accuracy : 72.25%
# Training model to test on subject 05 ...
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.58500, saving model to ../saved_models/best_CNN_model_for_s05_valence(2classes).h5
# Epoch 00002: val_categorical_accuracy improved from 0.58500 to 0.61750, saving model to ../saved_models/best_CNN_model_for_s05_valence(2classes).h5
# Epoch 00003: val_categorical_accuracy improved from 0.61750 to 0.66250, saving model to ../saved_models/best_CNN_model_for_s05_valence(2classes).h5
# Epoch 00004: val_categorical_accuracy improved from 0.66250 to 0.67250, saving model to ../saved_models/best_CNN_model_for_s05_valence(2classes).h5
# Epoch 00005: val_categorical_accuracy improved from 0.67250 to 0.68000, saving model to ../saved_models/best_CNN_model_for_s05_valence(2classes).h5
# Epoch 00006: val_categorical_accuracy did not improve
# Epoch 00007: val_categorical_accuracy did not improve
# Epoch 00008: val_categorical_accuracy did not improve
# Epoch 00009: val_categorical_accuracy did not improve
# Epoch 00010: val_categorical_accuracy improved from 0.68000 to 0.69500, saving model to ../saved_models/best_CNN_model_for_s05_valence(2classes).h5
# Epoch 00011: val_categorical_accuracy did not improve
# Epoch 00012: val_categorical_accuracy did not improve
# Epoch 00013: val_categorical_accuracy did not improve
# Epoch 00014: val_categorical_accuracy did not improve
# Epoch 00015: val_categorical_accuracy did not improve
# Epoch 00016: val_categorical_accuracy did not improve
# Epoch 00017: val_categorical_accuracy did not improve
# Epoch 00018: val_categorical_accuracy did not improve
# Epoch 00019: val_categorical_accuracy did not improve
# Epoch 00020: val_categorical_accuracy did not improve
# Epoch 00021: val_categorical_accuracy did not improve
# Epoch 00022: val_categorical_accuracy did not improve
# Epoch 00023: val_categorical_accuracy did not improve
# Epoch 00024: val_categorical_accuracy did not improve
# Epoch 00025: val_categorical_accuracy did not improve
# Epoch 00026: val_categorical_accuracy did not improve
# Epoch 00027: val_categorical_accuracy did not improve
# Epoch 00028: val_categorical_accuracy did not improve
# Epoch 00029: val_categorical_accuracy did not improve
# Epoch 00030: val_categorical_accuracy did not improve
# Epoch 00031: val_categorical_accuracy did not improve
# Epoch 00032: val_categorical_accuracy did not improve
# Epoch 00033: val_categorical_accuracy did not improve
# Epoch 00034: val_categorical_accuracy did not improve
# Epoch 00035: val_categorical_accuracy did not improve
# Epoch 00036: val_categorical_accuracy did not improve
# Epoch 00037: val_categorical_accuracy did not improve
# Epoch 00038: val_categorical_accuracy did not improve
# Epoch 00039: val_categorical_accuracy did not improve
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00041: val_categorical_accuracy did not improve
# Epoch 00042: val_categorical_accuracy did not improve
# Epoch 00043: val_categorical_accuracy did not improve
# Epoch 00044: val_categorical_accuracy did not improve
# Epoch 00045: val_categorical_accuracy did not improve
# Epoch 00046: val_categorical_accuracy did not improve
# Epoch 00047: val_categorical_accuracy did not improve
# Epoch 00048: val_categorical_accuracy did not improve
# Epoch 00049: val_categorical_accuracy did not improve
# Epoch 00050: val_categorical_accuracy did not improve
# 400/400 [==============================] - 0s 499us/step
# #### Result of CNN model for subject 05 #####
#
# Validation Loss: 0.632398695946 , Validation Accuracy : 69.5%
# Training model to test on subject 06 ...
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.75000, saving model to ../saved_models/best_CNN_model_for_s06_valence(2classes).h5
# Epoch 00002: val_categorical_accuracy improved from 0.75000 to 0.77250, saving model to ../saved_models/best_CNN_model_for_s06_valence(2classes).h5
# Epoch 00003: val_categorical_accuracy did not improve
# Epoch 00004: val_categorical_accuracy did not improve
# Epoch 00005: val_categorical_accuracy did not improve
# Epoch 00006: val_categorical_accuracy did not improve
# Epoch 00007: val_categorical_accuracy did not improve
# Epoch 00008: val_categorical_accuracy did not improve
# Epoch 00009: val_categorical_accuracy did not improve
# Epoch 00010: val_categorical_accuracy did not improve
# Epoch 00011: val_categorical_accuracy did not improve
# Epoch 00012: val_categorical_accuracy did not improve
# Epoch 00013: val_categorical_accuracy did not improve
# Epoch 00014: val_categorical_accuracy did not improve
# Epoch 00015: val_categorical_accuracy did not improve
# Epoch 00016: val_categorical_accuracy did not improve
# Epoch 00017: val_categorical_accuracy did not improve
# Epoch 00018: val_categorical_accuracy did not improve
# Epoch 00019: val_categorical_accuracy did not improve
# Epoch 00020: val_categorical_accuracy did not improve
# Epoch 00021: val_categorical_accuracy did not improve
# Epoch 00022: val_categorical_accuracy did not improve
# Epoch 00023: val_categorical_accuracy did not improve
# Epoch 00024: val_categorical_accuracy did not improve
# Epoch 00025: val_categorical_accuracy did not improve
# Epoch 00026: val_categorical_accuracy did not improve
# Epoch 00027: val_categorical_accuracy did not improve
# Epoch 00028: val_categorical_accuracy did not improve
# Epoch 00029: val_categorical_accuracy did not improve
# Epoch 00030: val_categorical_accuracy did not improve
# Epoch 00031: val_categorical_accuracy did not improve
# Epoch 00032: val_categorical_accuracy did not improve
# Epoch 00033: val_categorical_accuracy did not improve
# Epoch 00034: val_categorical_accuracy did not improve
# Epoch 00035: val_categorical_accuracy did not improve
# Epoch 00036: val_categorical_accuracy did not improve
# Epoch 00037: val_categorical_accuracy did not improve
# Epoch 00038: val_categorical_accuracy did not improve
# Epoch 00039: val_categorical_accuracy did not improve
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00041: val_categorical_accuracy did not improve
# Epoch 00042: val_categorical_accuracy did not improve
# Epoch 00043: val_categorical_accuracy did not improve
# Epoch 00044: val_categorical_accuracy did not improve
# Epoch 00045: val_categorical_accuracy did not improve
# Epoch 00046: val_categorical_accuracy did not improve
# Epoch 00047: val_categorical_accuracy did not improve
# Epoch 00048: val_categorical_accuracy did not improve
# Epoch 00049: val_categorical_accuracy did not improve
# Epoch 00050: val_categorical_accuracy did not improve
# 400/400 [==============================] - 0s 488us/step
# #### Result of CNN model for subject 06 #####
#
# Validation Loss: 0.603366754055 , Validation Accuracy : 77.25%
# Training model to test on subject 07 ...
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.63000, saving model to ../saved_models/best_CNN_model_for_s07_valence(2classes).h5
# Epoch 00002: val_categorical_accuracy did not improve
# Epoch 00003: val_categorical_accuracy did not improve
# Epoch 00004: val_categorical_accuracy did not improve
# Epoch 00005: val_categorical_accuracy improved from 0.63000 to 0.63000, saving model to ../saved_models/best_CNN_model_for_s07_valence(2classes).h5
# Epoch 00006: val_categorical_accuracy improved from 0.63000 to 0.63500, saving model to ../saved_models/best_CNN_model_for_s07_valence(2classes).h5
# Epoch 00007: val_categorical_accuracy improved from 0.63500 to 0.64750, saving model to ../saved_models/best_CNN_model_for_s07_valence(2classes).h5
# Epoch 00008: val_categorical_accuracy improved from 0.64750 to 0.66000, saving model to ../saved_models/best_CNN_model_for_s07_valence(2classes).h5
# Epoch 00009: val_categorical_accuracy improved from 0.66000 to 0.68250, saving model to ../saved_models/best_CNN_model_for_s07_valence(2classes).h5
# Epoch 00010: val_categorical_accuracy improved from 0.68250 to 0.69750, saving model to ../saved_models/best_CNN_model_for_s07_valence(2classes).h5
# Epoch 00011: val_categorical_accuracy did not improve
# Epoch 00012: val_categorical_accuracy improved from 0.69750 to 0.70750, saving model to ../saved_models/best_CNN_model_for_s07_valence(2classes).h5
# Epoch 00013: val_categorical_accuracy did not improve
# Epoch 00014: val_categorical_accuracy improved from 0.70750 to 0.71000, saving model to ../saved_models/best_CNN_model_for_s07_valence(2classes).h5
# Epoch 00015: val_categorical_accuracy did not improve
# Epoch 00016: val_categorical_accuracy improved from 0.71000 to 0.71250, saving model to ../saved_models/best_CNN_model_for_s07_valence(2classes).h5
# Epoch 00017: val_categorical_accuracy did not improve
# Epoch 00018: val_categorical_accuracy did not improve
# Epoch 00019: val_categorical_accuracy improved from 0.71250 to 0.71750, saving model to ../saved_models/best_CNN_model_for_s07_valence(2classes).h5
# Epoch 00020: val_categorical_accuracy did not improve
# Epoch 00021: val_categorical_accuracy improved from 0.71750 to 0.72000, saving model to ../saved_models/best_CNN_model_for_s07_valence(2classes).h5
# Epoch 00022: val_categorical_accuracy did not improve
# Epoch 00023: val_categorical_accuracy did not improve
# Epoch 00024: val_categorical_accuracy improved from 0.72000 to 0.72750, saving model to ../saved_models/best_CNN_model_for_s07_valence(2classes).h5
# Epoch 00025: val_categorical_accuracy did not improve
# Epoch 00026: val_categorical_accuracy did not improve
# Epoch 00027: val_categorical_accuracy improved from 0.72750 to 0.73250, saving model to ../saved_models/best_CNN_model_for_s07_valence(2classes).h5
# Epoch 00028: val_categorical_accuracy did not improve
# Epoch 00029: val_categorical_accuracy did not improve
# Epoch 00030: val_categorical_accuracy did not improve
# Epoch 00031: val_categorical_accuracy did not improve
# Epoch 00032: val_categorical_accuracy did not improve
# Epoch 00033: val_categorical_accuracy did not improve
# Epoch 00034: val_categorical_accuracy did not improve
# Epoch 00035: val_categorical_accuracy did not improve
# Epoch 00036: val_categorical_accuracy did not improve
# Epoch 00037: val_categorical_accuracy did not improve
# Epoch 00038: val_categorical_accuracy did not improve
# Epoch 00039: val_categorical_accuracy did not improve
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00041: val_categorical_accuracy did not improve
# Epoch 00042: val_categorical_accuracy did not improve
# Epoch 00043: val_categorical_accuracy did not improve
# Epoch 00044: val_categorical_accuracy improved from 0.73250 to 0.73250, saving model to ../saved_models/best_CNN_model_for_s07_valence(2classes).h5
# Epoch 00045: val_categorical_accuracy did not improve
# Epoch 00046: val_categorical_accuracy did not improve
# Epoch 00047: val_categorical_accuracy did not improve
# Epoch 00048: val_categorical_accuracy did not improve
# Epoch 00049: val_categorical_accuracy did not improve
# Epoch 00050: val_categorical_accuracy did not improve
# 400/400 [==============================] - 0s 490us/step
# #### Result of CNN model for subject 07 #####
#
# Validation Loss: 0.686208598018 , Validation Accuracy : 73.25%
# Training model to test on subject 08 ...
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.55000, saving model to ../saved_models/best_CNN_model_for_s08_valence(2classes).h5
# Epoch 00002: val_categorical_accuracy improved from 0.55000 to 0.56250, saving model to ../saved_models/best_CNN_model_for_s08_valence(2classes).h5
# Epoch 00003: val_categorical_accuracy improved from 0.56250 to 0.60750, saving model to ../saved_models/best_CNN_model_for_s08_valence(2classes).h5
# Epoch 00004: val_categorical_accuracy improved from 0.60750 to 0.61500, saving model to ../saved_models/best_CNN_model_for_s08_valence(2classes).h5
# Epoch 00005: val_categorical_accuracy improved from 0.61500 to 0.63750, saving model to ../saved_models/best_CNN_model_for_s08_valence(2classes).h5
# Epoch 00006: val_categorical_accuracy improved from 0.63750 to 0.67250, saving model to ../saved_models/best_CNN_model_for_s08_valence(2classes).h5
# Epoch 00007: val_categorical_accuracy did not improve
# Epoch 00008: val_categorical_accuracy improved from 0.67250 to 0.67750, saving model to ../saved_models/best_CNN_model_for_s08_valence(2classes).h5
# Epoch 00009: val_categorical_accuracy improved from 0.67750 to 0.67750, saving model to ../saved_models/best_CNN_model_for_s08_valence(2classes).h5
# Epoch 00010: val_categorical_accuracy improved from 0.67750 to 0.68000, saving model to ../saved_models/best_CNN_model_for_s08_valence(2classes).h5
# Epoch 00011: val_categorical_accuracy improved from 0.68000 to 0.68750, saving model to ../saved_models/best_CNN_model_for_s08_valence(2classes).h5
# Epoch 00012: val_categorical_accuracy did not improve
# Epoch 00013: val_categorical_accuracy did not improve
# Epoch 00014: val_categorical_accuracy did not improve
# Epoch 00015: val_categorical_accuracy improved from 0.68750 to 0.68750, saving model to ../saved_models/best_CNN_model_for_s08_valence(2classes).h5
# Epoch 00016: val_categorical_accuracy did not improve
# Epoch 00017: val_categorical_accuracy did not improve
# Epoch 00018: val_categorical_accuracy did not improve
# Epoch 00019: val_categorical_accuracy did not improve
# Epoch 00020: val_categorical_accuracy did not improve
# Epoch 00021: val_categorical_accuracy did not improve
# Epoch 00022: val_categorical_accuracy did not improve
# Epoch 00023: val_categorical_accuracy did not improve
# Epoch 00024: val_categorical_accuracy did not improve
# Epoch 00025: val_categorical_accuracy did not improve
# Epoch 00026: val_categorical_accuracy did not improve
# Epoch 00027: val_categorical_accuracy did not improve
# Epoch 00028: val_categorical_accuracy improved from 0.68750 to 0.69750, saving model to ../saved_models/best_CNN_model_for_s08_valence(2classes).h5
# Epoch 00029: val_categorical_accuracy did not improve
# Epoch 00030: val_categorical_accuracy did not improve
# Epoch 00031: val_categorical_accuracy did not improve
# Epoch 00032: val_categorical_accuracy improved from 0.69750 to 0.70000, saving model to ../saved_models/best_CNN_model_for_s08_valence(2classes).h5
# Epoch 00033: val_categorical_accuracy did not improve
# Epoch 00034: val_categorical_accuracy did not improve
# Epoch 00035: val_categorical_accuracy did not improve
# Epoch 00036: val_categorical_accuracy did not improve
# Epoch 00037: val_categorical_accuracy did not improve
# Epoch 00038: val_categorical_accuracy did not improve
# Epoch 00039: val_categorical_accuracy did not improve
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00041: val_categorical_accuracy did not improve
# Epoch 00042: val_categorical_accuracy did not improve
# Epoch 00043: val_categorical_accuracy did not improve
# Epoch 00044: val_categorical_accuracy did not improve
# Epoch 00045: val_categorical_accuracy did not improve
# Epoch 00046: val_categorical_accuracy did not improve
# Epoch 00047: val_categorical_accuracy did not improve
# Epoch 00048: val_categorical_accuracy did not improve
# Epoch 00049: val_categorical_accuracy did not improve
# Epoch 00050: val_categorical_accuracy did not improve
# 400/400 [==============================] - 0s 501us/step
# #### Result of CNN model for subject 08 #####
#
# Validation Loss: 0.582957959771 , Validation Accuracy : 70.0%
# Training model to test on subject 09 ...
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.63000, saving model to ../saved_models/best_CNN_model_for_s09_valence(2classes).h5
# Epoch 00002: val_categorical_accuracy improved from 0.63000 to 0.72250, saving model to ../saved_models/best_CNN_model_for_s09_valence(2classes).h5
# Epoch 00003: val_categorical_accuracy improved from 0.72250 to 0.73250, saving model to ../saved_models/best_CNN_model_for_s09_valence(2classes).h5
# Epoch 00004: val_categorical_accuracy did not improve
# Epoch 00005: val_categorical_accuracy did not improve
# Epoch 00006: val_categorical_accuracy did not improve
# Epoch 00007: val_categorical_accuracy did not improve
# Epoch 00008: val_categorical_accuracy did not improve
# Epoch 00009: val_categorical_accuracy did not improve
# Epoch 00010: val_categorical_accuracy did not improve
# Epoch 00011: val_categorical_accuracy did not improve
# Epoch 00012: val_categorical_accuracy did not improve
# Epoch 00013: val_categorical_accuracy did not improve
# Epoch 00014: val_categorical_accuracy did not improve
# Epoch 00015: val_categorical_accuracy did not improve
# Epoch 00016: val_categorical_accuracy did not improve
# Epoch 00017: val_categorical_accuracy did not improve
# Epoch 00018: val_categorical_accuracy did not improve
# Epoch 00019: val_categorical_accuracy did not improve
# Epoch 00020: val_categorical_accuracy did not improve
# Epoch 00021: val_categorical_accuracy did not improve
# Epoch 00022: val_categorical_accuracy did not improve
# Epoch 00023: val_categorical_accuracy did not improve
# Epoch 00024: val_categorical_accuracy did not improve
# Epoch 00025: val_categorical_accuracy did not improve
# Epoch 00026: val_categorical_accuracy did not improve
# Epoch 00027: val_categorical_accuracy did not improve
# Epoch 00028: val_categorical_accuracy did not improve
# Epoch 00029: val_categorical_accuracy did not improve
# Epoch 00030: val_categorical_accuracy did not improve
# Epoch 00031: val_categorical_accuracy did not improve
# Epoch 00032: val_categorical_accuracy did not improve
# Epoch 00033: val_categorical_accuracy did not improve
# Epoch 00034: val_categorical_accuracy did not improve
# Epoch 00035: val_categorical_accuracy did not improve
# Epoch 00036: val_categorical_accuracy did not improve
# Epoch 00037: val_categorical_accuracy did not improve
# Epoch 00038: val_categorical_accuracy did not improve
# Epoch 00039: val_categorical_accuracy did not improve
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00041: val_categorical_accuracy did not improve
# Epoch 00042: val_categorical_accuracy did not improve
# Epoch 00043: val_categorical_accuracy did not improve
# Epoch 00044: val_categorical_accuracy did not improve
# Epoch 00045: val_categorical_accuracy did not improve
# Epoch 00046: val_categorical_accuracy did not improve
# Epoch 00047: val_categorical_accuracy did not improve
# Epoch 00048: val_categorical_accuracy did not improve
# Epoch 00049: val_categorical_accuracy did not improve
# Epoch 00050: val_categorical_accuracy did not improve
# 400/400 [==============================] - 0s 498us/step
# #### Result of CNN model for subject 09 #####
#
# Validation Loss: 0.604820101261 , Validation Accuracy : 73.25%
# Training model to test on subject 10 ...
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.56250, saving model to ../saved_models/best_CNN_model_for_s10_valence(2classes).h5
# Epoch 00002: val_categorical_accuracy improved from 0.56250 to 0.59500, saving model to ../saved_models/best_CNN_model_for_s10_valence(2classes).h5
# Epoch 00003: val_categorical_accuracy improved from 0.59500 to 0.68750, saving model to ../saved_models/best_CNN_model_for_s10_valence(2classes).h5
# Epoch 00004: val_categorical_accuracy improved from 0.68750 to 0.72250, saving model to ../saved_models/best_CNN_model_for_s10_valence(2classes).h5
# Epoch 00005: val_categorical_accuracy improved from 0.72250 to 0.73250, saving model to ../saved_models/best_CNN_model_for_s10_valence(2classes).h5
# Epoch 00006: val_categorical_accuracy improved from 0.73250 to 0.76750, saving model to ../saved_models/best_CNN_model_for_s10_valence(2classes).h5
# Epoch 00007: val_categorical_accuracy improved from 0.76750 to 0.77000, saving model to ../saved_models/best_CNN_model_for_s10_valence(2classes).h5
# Epoch 00008: val_categorical_accuracy improved from 0.77000 to 0.78000, saving model to ../saved_models/best_CNN_model_for_s10_valence(2classes).h5
# Epoch 00009: val_categorical_accuracy did not improve
# Epoch 00010: val_categorical_accuracy did not improve
# Epoch 00011: val_categorical_accuracy did not improve
# Epoch 00012: val_categorical_accuracy improved from 0.78000 to 0.79500, saving model to ../saved_models/best_CNN_model_for_s10_valence(2classes).h5
# Epoch 00013: val_categorical_accuracy did not improve
# Epoch 00014: val_categorical_accuracy improved from 0.79500 to 0.80000, saving model to ../saved_models/best_CNN_model_for_s10_valence(2classes).h5
# Epoch 00015: val_categorical_accuracy did not improve
# Epoch 00016: val_categorical_accuracy did not improve
# Epoch 00017: val_categorical_accuracy did not improve
# Epoch 00018: val_categorical_accuracy did not improve
# Epoch 00019: val_categorical_accuracy improved from 0.80000 to 0.80250, saving model to ../saved_models/best_CNN_model_for_s10_valence(2classes).h5
# Epoch 00020: val_categorical_accuracy did not improve
# Epoch 00021: val_categorical_accuracy did not improve
# Epoch 00022: val_categorical_accuracy did not improve
# Epoch 00023: val_categorical_accuracy did not improve
# Epoch 00024: val_categorical_accuracy did not improve
# Epoch 00025: val_categorical_accuracy did not improve
# Epoch 00026: val_categorical_accuracy did not improve
# Epoch 00027: val_categorical_accuracy did not improve
# Epoch 00028: val_categorical_accuracy did not improve
# Epoch 00029: val_categorical_accuracy did not improve
# Epoch 00030: val_categorical_accuracy did not improve
# Epoch 00031: val_categorical_accuracy did not improve
# Epoch 00032: val_categorical_accuracy did not improve
# Epoch 00033: val_categorical_accuracy did not improve
# Epoch 00034: val_categorical_accuracy did not improve
# Epoch 00035: val_categorical_accuracy did not improve
# Epoch 00036: val_categorical_accuracy did not improve
# Epoch 00037: val_categorical_accuracy did not improve
# Epoch 00038: val_categorical_accuracy did not improve
# Epoch 00039: val_categorical_accuracy did not improve
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00041: val_categorical_accuracy did not improve
# Epoch 00042: val_categorical_accuracy did not improve
# Epoch 00043: val_categorical_accuracy did not improve
# Epoch 00044: val_categorical_accuracy did not improve
# Epoch 00045: val_categorical_accuracy did not improve
# Epoch 00046: val_categorical_accuracy did not improve
# Epoch 00047: val_categorical_accuracy did not improve
# Epoch 00048: val_categorical_accuracy did not improve
# Epoch 00049: val_categorical_accuracy did not improve
# Epoch 00050: val_categorical_accuracy did not improve
# 400/400 [==============================] - 0s 499us/step
# #### Result of CNN model for subject 10 #####
#
# Validation Loss: 0.516217848063 , Validation Accuracy : 80.25%
# Training model to test on subject 11 ...
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.50750, saving model to ../saved_models/best_CNN_model_for_s11_valence(2classes).h5
# Epoch 00002: val_categorical_accuracy improved from 0.50750 to 0.52750, saving model to ../saved_models/best_CNN_model_for_s11_valence(2classes).h5
# Epoch 00003: val_categorical_accuracy improved from 0.52750 to 0.54000, saving model to ../saved_models/best_CNN_model_for_s11_valence(2classes).h5
# Epoch 00004: val_categorical_accuracy improved from 0.54000 to 0.56250, saving model to ../saved_models/best_CNN_model_for_s11_valence(2classes).h5
# Epoch 00005: val_categorical_accuracy improved from 0.56250 to 0.59500, saving model to ../saved_models/best_CNN_model_for_s11_valence(2classes).h5
# Epoch 00006: val_categorical_accuracy did not improve
# Epoch 00007: val_categorical_accuracy improved from 0.59500 to 0.65000, saving model to ../saved_models/best_CNN_model_for_s11_valence(2classes).h5
# Epoch 00008: val_categorical_accuracy improved from 0.65000 to 0.68250, saving model to ../saved_models/best_CNN_model_for_s11_valence(2classes).h5
# Epoch 00009: val_categorical_accuracy improved from 0.68250 to 0.68500, saving model to ../saved_models/best_CNN_model_for_s11_valence(2classes).h5
# Epoch 00010: val_categorical_accuracy improved from 0.68500 to 0.69000, saving model to ../saved_models/best_CNN_model_for_s11_valence(2classes).h5
# Epoch 00011: val_categorical_accuracy improved from 0.69000 to 0.69750, saving model to ../saved_models/best_CNN_model_for_s11_valence(2classes).h5
# Epoch 00012: val_categorical_accuracy improved from 0.69750 to 0.75000, saving model to ../saved_models/best_CNN_model_for_s11_valence(2classes).h5
# Epoch 00013: val_categorical_accuracy did not improve
# Epoch 00014: val_categorical_accuracy did not improve
# Epoch 00015: val_categorical_accuracy did not improve
# Epoch 00016: val_categorical_accuracy did not improve
# Epoch 00017: val_categorical_accuracy did not improve
# Epoch 00018: val_categorical_accuracy improved from 0.75000 to 0.77250, saving model to ../saved_models/best_CNN_model_for_s11_valence(2classes).h5
# Epoch 00019: val_categorical_accuracy did not improve
# Epoch 00020: val_categorical_accuracy did not improve
# Epoch 00021: val_categorical_accuracy did not improve
# Epoch 00022: val_categorical_accuracy did not improve
# Epoch 00023: val_categorical_accuracy did not improve
# Epoch 00024: val_categorical_accuracy did not improve
# Epoch 00025: val_categorical_accuracy improved from 0.77250 to 0.77500, saving model to ../saved_models/best_CNN_model_for_s11_valence(2classes).h5
# Epoch 00026: val_categorical_accuracy did not improve
# Epoch 00027: val_categorical_accuracy did not improve
# Epoch 00028: val_categorical_accuracy did not improve
# Epoch 00029: val_categorical_accuracy did not improve
# Epoch 00030: val_categorical_accuracy did not improve
# Epoch 00031: val_categorical_accuracy did not improve
# Epoch 00032: val_categorical_accuracy did not improve
# Epoch 00033: val_categorical_accuracy did not improve
# Epoch 00034: val_categorical_accuracy did not improve
# Epoch 00035: val_categorical_accuracy did not improve
# Epoch 00036: val_categorical_accuracy did not improve
# Epoch 00037: val_categorical_accuracy did not improve
# Epoch 00038: val_categorical_accuracy did not improve
# Epoch 00039: val_categorical_accuracy did not improve
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00041: val_categorical_accuracy did not improve
# Epoch 00042: val_categorical_accuracy did not improve
# Epoch 00043: val_categorical_accuracy did not improve
# Epoch 00044: val_categorical_accuracy did not improve
# Epoch 00045: val_categorical_accuracy did not improve
# Epoch 00046: val_categorical_accuracy did not improve
# Epoch 00047: val_categorical_accuracy did not improve
# Epoch 00048: val_categorical_accuracy improved from 0.77500 to 0.78000, saving model to ../saved_models/best_CNN_model_for_s11_valence(2classes).h5
# Epoch 00049: val_categorical_accuracy did not improve
# Epoch 00050: val_categorical_accuracy did not improve
# 400/400 [==============================] - 0s 498us/step
# #### Result of CNN model for subject 11 #####
#
# Validation Loss: 0.495525729656 , Validation Accuracy : 78.0%
# Training model to test on subject 12 ...
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.52750, saving model to ../saved_models/best_CNN_model_for_s12_valence(2classes).h5
# Epoch 00002: val_categorical_accuracy improved from 0.52750 to 0.67000, saving model to ../saved_models/best_CNN_model_for_s12_valence(2classes).h5
# Epoch 00003: val_categorical_accuracy improved from 0.67000 to 0.74750, saving model to ../saved_models/best_CNN_model_for_s12_valence(2classes).h5
# Epoch 00004: val_categorical_accuracy improved from 0.74750 to 0.75250, saving model to ../saved_models/best_CNN_model_for_s12_valence(2classes).h5
# Epoch 00005: val_categorical_accuracy improved from 0.75250 to 0.76000, saving model to ../saved_models/best_CNN_model_for_s12_valence(2classes).h5
# Epoch 00006: val_categorical_accuracy improved from 0.76000 to 0.76250, saving model to ../saved_models/best_CNN_model_for_s12_valence(2classes).h5
# Epoch 00007: val_categorical_accuracy did not improve
# Epoch 00008: val_categorical_accuracy improved from 0.76250 to 0.77250, saving model to ../saved_models/best_CNN_model_for_s12_valence(2classes).h5
# Epoch 00009: val_categorical_accuracy did not improve
# Epoch 00010: val_categorical_accuracy did not improve
# Epoch 00011: val_categorical_accuracy improved from 0.77250 to 0.78000, saving model to ../saved_models/best_CNN_model_for_s12_valence(2classes).h5
# Epoch 00012: val_categorical_accuracy did not improve
# Epoch 00013: val_categorical_accuracy did not improve
# Epoch 00014: val_categorical_accuracy did not improve
# Epoch 00015: val_categorical_accuracy improved from 0.78000 to 0.78250, saving model to ../saved_models/best_CNN_model_for_s12_valence(2classes).h5
# Epoch 00016: val_categorical_accuracy did not improve
# Epoch 00017: val_categorical_accuracy did not improve
# Epoch 00018: val_categorical_accuracy did not improve
# Epoch 00019: val_categorical_accuracy did not improve
# Epoch 00020: val_categorical_accuracy did not improve
# Epoch 00021: val_categorical_accuracy did not improve
# Epoch 00022: val_categorical_accuracy did not improve
# Epoch 00023: val_categorical_accuracy did not improve
# Epoch 00024: val_categorical_accuracy improved from 0.78250 to 0.78250, saving model to ../saved_models/best_CNN_model_for_s12_valence(2classes).h5
# Epoch 00025: val_categorical_accuracy did not improve
# Epoch 00026: val_categorical_accuracy did not improve
# Epoch 00027: val_categorical_accuracy did not improve
# Epoch 00028: val_categorical_accuracy improved from 0.78250 to 0.78500, saving model to ../saved_models/best_CNN_model_for_s12_valence(2classes).h5
# Epoch 00029: val_categorical_accuracy did not improve
# Epoch 00030: val_categorical_accuracy did not improve
# Epoch 00031: val_categorical_accuracy did not improve
# Epoch 00032: val_categorical_accuracy did not improve
# Epoch 00033: val_categorical_accuracy did not improve
# Epoch 00034: val_categorical_accuracy did not improve
# Epoch 00035: val_categorical_accuracy did not improve
# Epoch 00036: val_categorical_accuracy did not improve
# Epoch 00037: val_categorical_accuracy did not improve
# Epoch 00038: val_categorical_accuracy improved from 0.78500 to 0.78500, saving model to ../saved_models/best_CNN_model_for_s12_valence(2classes).h5
# Epoch 00039: val_categorical_accuracy did not improve
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00041: val_categorical_accuracy did not improve
# Epoch 00042: val_categorical_accuracy did not improve
# Epoch 00043: val_categorical_accuracy did not improve
# Epoch 00044: val_categorical_accuracy did not improve
# Epoch 00045: val_categorical_accuracy did not improve
# Epoch 00046: val_categorical_accuracy improved from 0.78500 to 0.78750, saving model to ../saved_models/best_CNN_model_for_s12_valence(2classes).h5
# Epoch 00047: val_categorical_accuracy did not improve
# Epoch 00048: val_categorical_accuracy did not improve
# Epoch 00049: val_categorical_accuracy did not improve
# Epoch 00050: val_categorical_accuracy did not improve
# 400/400 [==============================] - 0s 503us/step
# #### Result of CNN model for subject 12 #####
#
# Validation Loss: 0.507657996416 , Validation Accuracy : 78.75%
# Training model to test on subject 13 ...
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.50250, saving model to ../saved_models/best_CNN_model_for_s13_valence(2classes).h5
# Epoch 00002: val_categorical_accuracy improved from 0.50250 to 0.57750, saving model to ../saved_models/best_CNN_model_for_s13_valence(2classes).h5
# Epoch 00003: val_categorical_accuracy improved from 0.57750 to 0.69750, saving model to ../saved_models/best_CNN_model_for_s13_valence(2classes).h5
# Epoch 00004: val_categorical_accuracy did not improve
# Epoch 00005: val_categorical_accuracy improved from 0.69750 to 0.70250, saving model to ../saved_models/best_CNN_model_for_s13_valence(2classes).h5
# Epoch 00006: val_categorical_accuracy improved from 0.70250 to 0.70750, saving model to ../saved_models/best_CNN_model_for_s13_valence(2classes).h5
# Epoch 00007: val_categorical_accuracy did not improve
# Epoch 00008: val_categorical_accuracy improved from 0.70750 to 0.70750, saving model to ../saved_models/best_CNN_model_for_s13_valence(2classes).h5
# Epoch 00009: val_categorical_accuracy improved from 0.70750 to 0.72500, saving model to ../saved_models/best_CNN_model_for_s13_valence(2classes).h5
# Epoch 00010: val_categorical_accuracy improved from 0.72500 to 0.72750, saving model to ../saved_models/best_CNN_model_for_s13_valence(2classes).h5
# Epoch 00011: val_categorical_accuracy did not improve
# Epoch 00012: val_categorical_accuracy improved from 0.72750 to 0.73000, saving model to ../saved_models/best_CNN_model_for_s13_valence(2classes).h5
# Epoch 00013: val_categorical_accuracy did not improve
# Epoch 00014: val_categorical_accuracy did not improve
# Epoch 00015: val_categorical_accuracy did not improve
# Epoch 00016: val_categorical_accuracy improved from 0.73000 to 0.73500, saving model to ../saved_models/best_CNN_model_for_s13_valence(2classes).h5
# Epoch 00017: val_categorical_accuracy did not improve
# Epoch 00018: val_categorical_accuracy did not improve
# ...
# Epoch 00027: val_categorical_accuracy did not improve
# Epoch 00028: val_categorical_accuracy did not improve
# Epoch 00029: val_categorical_accuracy did not improve
# Epoch 00030: val_categorical_accuracy improved from 0.81000 to 0.81250, saving model to ../saved_models/best_CNN_model_for_s28_valence(2classes).h5
# Epoch 00031: val_categorical_accuracy did not improve
# Epoch 00032: val_categorical_accuracy did not improve
# Epoch 00033: val_categorical_accuracy did not improve
# Epoch 00034: val_categorical_accuracy did not improve
# Epoch 00035: val_categorical_accuracy did not improve
# Epoch 00036: val_categorical_accuracy did not improve
# Epoch 00037: val_categorical_accuracy did not improve
# Epoch 00038: val_categorical_accuracy did not improve
# Epoch 00039: val_categorical_accuracy did not improve
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00041: val_categorical_accuracy improved from 0.81250 to 0.81500, saving model to ../saved_models/best_CNN_model_for_s28_valence(2classes).h5
# Epoch 00042: val_categorical_accuracy did not improve
# Epoch 00043: val_categorical_accuracy did not improve
# Epoch 00044: val_categorical_accuracy did not improve
# Epoch 00045: val_categorical_accuracy did not improve
# Epoch 00046: val_categorical_accuracy did not improve
# Epoch 00047: val_categorical_accuracy did not improve
# Epoch 00048: val_categorical_accuracy did not improve
# Epoch 00049: val_categorical_accuracy did not improve
# Epoch 00050: val_categorical_accuracy did not improve
# 400/400 [==============================] - 0s 503us/step
# #### Result of CNN model for subject 28 #####
#
# Validation Loss: 0.493518266678 , Validation Accuracy : 81.5%
# Training model to test on subject 29 ...
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.57500, saving model to ../saved_models/best_CNN_model_for_s29_valence(2classes).h5
# Epoch 00002: val_categorical_accuracy did not improve
# Epoch 00003: val_categorical_accuracy did not improve
# Epoch 00004: val_categorical_accuracy improved from 0.57500 to 0.60250, saving model to ../saved_models/best_CNN_model_for_s29_valence(2classes).h5
# Epoch 00005: val_categorical_accuracy improved from 0.60250 to 0.61750, saving model to ../saved_models/best_CNN_model_for_s29_valence(2classes).h5
# Epoch 00006: val_categorical_accuracy improved from 0.61750 to 0.64750, saving model to ../saved_models/best_CNN_model_for_s29_valence(2classes).h5
# Epoch 00007: val_categorical_accuracy did not improve
# Epoch 00008: val_categorical_accuracy improved from 0.64750 to 0.66750, saving model to ../saved_models/best_CNN_model_for_s29_valence(2classes).h5
# Epoch 00009: val_categorical_accuracy improved from 0.66750 to 0.67500, saving model to ../saved_models/best_CNN_model_for_s29_valence(2classes).h5
# Epoch 00010: val_categorical_accuracy improved from 0.67500 to 0.69000, saving model to ../saved_models/best_CNN_model_for_s29_valence(2classes).h5
# Epoch 00011: val_categorical_accuracy did not improve
# Epoch 00012: val_categorical_accuracy did not improve
# Epoch 00013: val_categorical_accuracy did not improve
# Epoch 00014: val_categorical_accuracy improved from 0.69000 to 0.69250, saving model to ../saved_models/best_CNN_model_for_s29_valence(2classes).h5
# Epoch 00015: val_categorical_accuracy did not improve
# Epoch 00016: val_categorical_accuracy improved from 0.69250 to 0.69250, saving model to ../saved_models/best_CNN_model_for_s29_valence(2classes).h5
# Epoch 00017: val_categorical_accuracy improved from 0.69250 to 0.69500, saving model to ../saved_models/best_CNN_model_for_s29_valence(2classes).h5
# Epoch 00018: val_categorical_accuracy did not improve
# Epoch 00019: val_categorical_accuracy did not improve
# Epoch 00020: val_categorical_accuracy did not improve
# Epoch 00021: val_categorical_accuracy improved from 0.69500 to 0.69500, saving model to ../saved_models/best_CNN_model_for_s29_valence(2classes).h5
# Epoch 00022: val_categorical_accuracy did not improve
# Epoch 00023: val_categorical_accuracy did not improve
# Epoch 00024: val_categorical_accuracy did not improve
# Epoch 00025: val_categorical_accuracy did not improve
# Epoch 00026: val_categorical_accuracy did not improve
# Epoch 00027: val_categorical_accuracy did not improve
# Epoch 00028: val_categorical_accuracy did not improve
# Epoch 00029: val_categorical_accuracy did not improve
# Epoch 00030: val_categorical_accuracy did not improve
# Epoch 00031: val_categorical_accuracy did not improve
# Epoch 00032: val_categorical_accuracy did not improve
# Epoch 00033: val_categorical_accuracy improved from 0.69500 to 0.69750, saving model to ../saved_models/best_CNN_model_for_s29_valence(2classes).h5
# Epoch 00034: val_categorical_accuracy did not improve
# Epoch 00035: val_categorical_accuracy did not improve
# Epoch 00036: val_categorical_accuracy did not improve
# Epoch 00037: val_categorical_accuracy improved from 0.69750 to 0.70250, saving model to ../saved_models/best_CNN_model_for_s29_valence(2classes).h5
# Epoch 00038: val_categorical_accuracy did not improve
# Epoch 00039: val_categorical_accuracy did not improve
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00041: val_categorical_accuracy did not improve
# Epoch 00042: val_categorical_accuracy did not improve
# Epoch 00043: val_categorical_accuracy did not improve
# Epoch 00044: val_categorical_accuracy did not improve
# Epoch 00045: val_categorical_accuracy did not improve
# Epoch 00046: val_categorical_accuracy did not improve
# Epoch 00047: val_categorical_accuracy did not improve
# Epoch 00048: val_categorical_accuracy did not improve
# Epoch 00049: val_categorical_accuracy did not improve
# Epoch 00050: val_categorical_accuracy did not improve
# 400/400 [==============================] - 0s 496us/step
# #### Result of CNN model for subject 29 #####
#
# Validation Loss: 0.540035676956 , Validation Accuracy : 70.25%
# Training model to test on subject 30 ...
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.68500, saving model to ../saved_models/best_CNN_model_for_s30_valence(2classes).h5
# Epoch 00002: val_categorical_accuracy did not improve
# Epoch 00003: val_categorical_accuracy improved from 0.68500 to 0.71500, saving model to ../saved_models/best_CNN_model_for_s30_valence(2classes).h5
# Epoch 00004: val_categorical_accuracy did not improve
# Epoch 00005: val_categorical_accuracy improved from 0.71500 to 0.72500, saving model to ../saved_models/best_CNN_model_for_s30_valence(2classes).h5
# Epoch 00006: val_categorical_accuracy did not improve
# Epoch 00007: val_categorical_accuracy did not improve
# Epoch 00008: val_categorical_accuracy did not improve
# Epoch 00009: val_categorical_accuracy did not improve
# Epoch 00010: val_categorical_accuracy did not improve
# Epoch 00011: val_categorical_accuracy did not improve
# Epoch 00012: val_categorical_accuracy did not improve
# Epoch 00013: val_categorical_accuracy did not improve
# Epoch 00014: val_categorical_accuracy did not improve
# Epoch 00015: val_categorical_accuracy did not improve
# Epoch 00016: val_categorical_accuracy did not improve
# Epoch 00017: val_categorical_accuracy did not improve
# Epoch 00018: val_categorical_accuracy did not improve
# Epoch 00019: val_categorical_accuracy did not improve
# Epoch 00020: val_categorical_accuracy did not improve
# Epoch 00021: val_categorical_accuracy did not improve
# Epoch 00022: val_categorical_accuracy did not improve
# Epoch 00023: val_categorical_accuracy did not improve
# Epoch 00024: val_categorical_accuracy did not improve
# Epoch 00025: val_categorical_accuracy did not improve
# Epoch 00026: val_categorical_accuracy did not improve
# Epoch 00027: val_categorical_accuracy did not improve
# Epoch 00028: val_categorical_accuracy did not improve
# Epoch 00029: val_categorical_accuracy did not improve
# Epoch 00030: val_categorical_accuracy did not improve
# Epoch 00031: val_categorical_accuracy did not improve
# Epoch 00032: val_categorical_accuracy did not improve
# Epoch 00033: val_categorical_accuracy did not improve
# Epoch 00034: val_categorical_accuracy did not improve
# Epoch 00035: val_categorical_accuracy did not improve
# Epoch 00036: val_categorical_accuracy did not improve
# Epoch 00037: val_categorical_accuracy did not improve
# Epoch 00038: val_categorical_accuracy did not improve
# Epoch 00039: val_categorical_accuracy did not improve
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00041: val_categorical_accuracy did not improve
# Epoch 00042: val_categorical_accuracy did not improve
# Epoch 00043: val_categorical_accuracy did not improve
# Epoch 00044: val_categorical_accuracy did not improve
# Epoch 00045: val_categorical_accuracy did not improve
# Epoch 00046: val_categorical_accuracy did not improve
# Epoch 00047: val_categorical_accuracy did not improve
# Epoch 00048: val_categorical_accuracy did not improve
# Epoch 00049: val_categorical_accuracy did not improve
# Epoch 00050: val_categorical_accuracy did not improve
# 400/400 [==============================] - 0s 499us/step
# #### Result of CNN model for subject 30 #####
#
# Validation Loss: 0.577966849804 , Validation Accuracy : 72.5%
# Training model to test on subject 31 ...
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.63000, saving model to ../saved_models/best_CNN_model_for_s31_valence(2classes).h5
# Epoch 00002: val_categorical_accuracy improved from 0.63000 to 0.67750, saving model to ../saved_models/best_CNN_model_for_s31_valence(2classes).h5
# Epoch 00003: val_categorical_accuracy improved from 0.67750 to 0.75250, saving model to ../saved_models/best_CNN_model_for_s31_valence(2classes).h5
# Epoch 00004: val_categorical_accuracy improved from 0.75250 to 0.78000, saving model to ../saved_models/best_CNN_model_for_s31_valence(2classes).h5
# Epoch 00005: val_categorical_accuracy improved from 0.78000 to 0.79000, saving model to ../saved_models/best_CNN_model_for_s31_valence(2classes).h5
# Epoch 00006: val_categorical_accuracy improved from 0.79000 to 0.80750, saving model to ../saved_models/best_CNN_model_for_s31_valence(2classes).h5
# Epoch 00007: val_categorical_accuracy did not improve
# Epoch 00008: val_categorical_accuracy did not improve
# Epoch 00009: val_categorical_accuracy did not improve
# Epoch 00010: val_categorical_accuracy did not improve
# Epoch 00011: val_categorical_accuracy did not improve
# Epoch 00012: val_categorical_accuracy did not improve
# Epoch 00013: val_categorical_accuracy did not improve
# Epoch 00014: val_categorical_accuracy did not improve
# Epoch 00015: val_categorical_accuracy did not improve
# Epoch 00016: val_categorical_accuracy did not improve
# Epoch 00017: val_categorical_accuracy did not improve
# Epoch 00018: val_categorical_accuracy did not improve
# Epoch 00019: val_categorical_accuracy did not improve
# Epoch 00020: val_categorical_accuracy did not improve
# Epoch 00021: val_categorical_accuracy did not improve
# Epoch 00022: val_categorical_accuracy did not improve
# Epoch 00023: val_categorical_accuracy did not improve
# Epoch 00024: val_categorical_accuracy did not improve
# Epoch 00025: val_categorical_accuracy did not improve
# Epoch 00026: val_categorical_accuracy did not improve
# Epoch 00027: val_categorical_accuracy did not improve
# Epoch 00028: val_categorical_accuracy did not improve
# Epoch 00029: val_categorical_accuracy did not improve
# Epoch 00030: val_categorical_accuracy did not improve
# Epoch 00031: val_categorical_accuracy did not improve
# Epoch 00032: val_categorical_accuracy did not improve
# Epoch 00033: val_categorical_accuracy did not improve
# Epoch 00034: val_categorical_accuracy did not improve
# Epoch 00035: val_categorical_accuracy did not improve
# Epoch 00036: val_categorical_accuracy did not improve
# Epoch 00037: val_categorical_accuracy did not improve
# Epoch 00038: val_categorical_accuracy did not improve
# Epoch 00039: val_categorical_accuracy did not improve
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00041: val_categorical_accuracy did not improve
# Epoch 00042: val_categorical_accuracy did not improve
# Epoch 00043: val_categorical_accuracy did not improve
# Epoch 00044: val_categorical_accuracy did not improve
# Epoch 00045: val_categorical_accuracy did not improve
# Epoch 00046: val_categorical_accuracy did not improve
# Epoch 00047: val_categorical_accuracy did not improve
# Epoch 00048: val_categorical_accuracy did not improve
# Epoch 00049: val_categorical_accuracy did not improve
# Epoch 00050: val_categorical_accuracy did not improve
# 400/400 [==============================] - 0s 503us/step
# #### Result of CNN model for subject 31 #####
#
# Validation Loss: 0.549249711037 , Validation Accuracy : 80.75%
# Training model to test on subject 32 ...
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.57250, saving model to ../saved_models/best_CNN_model_for_s32_valence(2classes).h5
# Epoch 00002: val_categorical_accuracy improved from 0.57250 to 0.60750, saving model to ../saved_models/best_CNN_model_for_s32_valence(2classes).h5
# Epoch 00003: val_categorical_accuracy improved from 0.60750 to 0.67250, saving model to ../saved_models/best_CNN_model_for_s32_valence(2classes).h5
# Epoch 00004: val_categorical_accuracy improved from 0.67250 to 0.71000, saving model to ../saved_models/best_CNN_model_for_s32_valence(2classes).h5
# Epoch 00005: val_categorical_accuracy improved from 0.71000 to 0.72000, saving model to ../saved_models/best_CNN_model_for_s32_valence(2classes).h5
# Epoch 00006: val_categorical_accuracy improved from 0.72000 to 0.72250, saving model to ../saved_models/best_CNN_model_for_s32_valence(2classes).h5
# Epoch 00007: val_categorical_accuracy did not improve
# Epoch 00008: val_categorical_accuracy did not improve
# Epoch 00009: val_categorical_accuracy improved from 0.72250 to 0.72750, saving model to ../saved_models/best_CNN_model_for_s32_valence(2classes).h5
# Epoch 00010: val_categorical_accuracy did not improve
# Epoch 00011: val_categorical_accuracy did not improve
# Epoch 00012: val_categorical_accuracy did not improve
# Epoch 00013: val_categorical_accuracy did not improve
# Epoch 00014: val_categorical_accuracy did not improve
# Epoch 00015: val_categorical_accuracy did not improve
# Epoch 00016: val_categorical_accuracy did not improve
# Epoch 00017: val_categorical_accuracy did not improve
# Epoch 00018: val_categorical_accuracy did not improve
# Epoch 00019: val_categorical_accuracy did not improve
# Epoch 00020: val_categorical_accuracy did not improve
# Epoch 00021: val_categorical_accuracy did not improve
# Epoch 00022: val_categorical_accuracy did not improve
# Epoch 00023: val_categorical_accuracy did not improve
# Epoch 00024: val_categorical_accuracy did not improve
# Epoch 00025: val_categorical_accuracy did not improve
# Epoch 00026: val_categorical_accuracy did not improve
# Epoch 00027: val_categorical_accuracy did not improve
# Epoch 00028: val_categorical_accuracy did not improve
# Epoch 00029: val_categorical_accuracy did not improve
# Epoch 00030: val_categorical_accuracy did not improve
# Epoch 00031: val_categorical_accuracy did not improve
# Epoch 00032: val_categorical_accuracy did not improve
# Epoch 00033: val_categorical_accuracy did not improve
# Epoch 00034: val_categorical_accuracy did not improve
# Epoch 00035: val_categorical_accuracy did not improve
# Epoch 00036: val_categorical_accuracy did not improve
# Epoch 00037: val_categorical_accuracy did not improve
# Epoch 00038: val_categorical_accuracy did not improve
# Epoch 00039: val_categorical_accuracy did not improve
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00041: val_categorical_accuracy did not improve
# Epoch 00042: val_categorical_accuracy did not improve
# Epoch 00043: val_categorical_accuracy did not improve
# Epoch 00044: val_categorical_accuracy did not improve
# Epoch 00045: val_categorical_accuracy did not improve
# Epoch 00046: val_categorical_accuracy did not improve
# Epoch 00047: val_categorical_accuracy did not improve
# Epoch 00048: val_categorical_accuracy did not improve
# Epoch 00049: val_categorical_accuracy did not improve
# Epoch 00050: val_categorical_accuracy did not improve
# 400/400 [==============================] - 0s 500us/step
# #### Result of CNN model for subject 32 #####
#
# Validation Loss: 0.596571815014 , Validation Accuracy : 72.75%

# %% [markdown]
# # Accuracies per subject and average accuracy

# %%
min_acc_subject_idx, max_acc_subject_idx = np.argmin(accuracies), np.argmax(accuracies)

avg_acc =  reduce(lambda x, y: x + y, accuracies) / len(accuracies)

print 5*'#' + ' Accuracies per subject ' + 5*'#'

print 'Subject {} has the minimum accuracy : {}%'.format(min_acc_subject_idx + 1, min(accuracies)*100)
print 'Subject {} has the maximum accuracy : {}%'.format(max_acc_subject_idx + 1, max(accuracies)*100)
print 'Average accuracy : {}%'.format(avg_acc*100)

for subj in enumerate(accuracies):
    print 'Accuracy of Subject {} : {}%'.format(subj[0]+1, subj[1]*100)
# Out:
# ##### Accuracies per subject #####
# Subject 16 has the minimum accuracy : 52.25%
# Subject 15 has the maximum accuracy : 88.0%
# Average accuracy : 76.6640625%
# Accuracy of Subject 1 : 73.75%
# Accuracy of Subject 2 : 78.0%
# Accuracy of Subject 3 : 76.0%
# Accuracy of Subject 4 : 72.25%
# Accuracy of Subject 5 : 69.5%
# Accuracy of Subject 6 : 77.25%
# Accuracy of Subject 7 : 73.25%
# Accuracy of Subject 8 : 70.0%
# Accuracy of Subject 9 : 73.25%
# Accuracy of Subject 10 : 80.25%
# Accuracy of Subject 11 : 78.0%
# Accuracy of Subject 12 : 78.75%
# Accuracy of Subject 13 : 74.5%
# Accuracy of Subject 14 : 79.25%
# Accuracy of Subject 15 : 88.0%
# Accuracy of Subject 16 : 52.25%
# Accuracy of Subject 17 : 76.75%
# Accuracy of Subject 18 : 79.25%
# Accuracy of Subject 19 : 86.5%
# Accuracy of Subject 20 : 86.5%
# Accuracy of Subject 21 : 73.25%
# Accuracy of Subject 22 : 79.75%
# Accuracy of Subject 23 : 72.25%
# Accuracy of Subject 24 : 83.75%
# Accuracy of Subject 25 : 78.5%
# Accuracy of Subject 26 : 85.25%
# Accuracy of Subject 27 : 79.5%
# Accuracy of Subject 28 : 81.5%
# Accuracy of Subject 29 : 70.25%
# Accuracy of Subject 30 : 72.5%
# Accuracy of Subject 31 : 80.75%
# Accuracy of Subject 32 : 72.75%

# %% [markdown]
# # Average accuracy after removing subject 16

# %%
naccuracies = accuracies[:15]+accuracies[16:]
np.sum(naccuracies)/len(naccuracies)
# Out:
# 0.77451612903225819

# %% [markdown]
# # Load the pre processed data and models

# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt
import time
import pickle
from keras.models import load_model
from keras import metrics
import models.nnmodels as nn


import gc
gc.enable()
seed = 0
np.random.seed(seed)
# %matplotlib inline


# Load the train data
with open('../pickles/Normalized_data_reduced.pickle', 'rb') as handle:
    Normalized_data_reduced = pickle.load(handle)

# Load labels
with open('../pickles/augmented_valence_labels.pickle', 'rb') as handle:
    augmented_valence_labels = pickle.load(handle)

# Get features and label for subject i
X_val = Normalized_data_reduced[0]
X_val = np.expand_dims(X_val, axis=1)
y_val = augmented_valence_labels[0]

# Initialize the model 
model = nn.CNN(num_classes=2, emotion='valence')
    
    
# Pre-trained model path
filepath="../saved_models/best_CNN_model_for_s01_valence(2classes).h5"
    
# Load the pretrained weights
model.load_weights(filepath)
    
# Predict the scores (loss, accuracy)
scores = model.predict(x=X_val)

print 'Subject accuracy : {.2f}'.format(scores[1]*100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-05ca23c1c5b4> in <module>()
#      30
#      31 # Initialize the model
# ---> 32 model = nn.CNN(num_classes=2, emotion='valence')
#      33
#      34
#
# /home/omid/course_project/models/nnmodels.py in CNN(num_classes, emotion, input_shape)
#      28
#      29     model.add(Conv2D(128,  kernel_size=(3,3), padding='valid', input_shape=(1,40,29),
# ---> 30                      data_format='channels_first'))
#      31
#      32     model.add(Activation(act_func))
#
# /home/omid/venv2/local/lib/python2.7/site-packages/Keras-2.1.2-py2.7.egg/keras/legacy/interfaces.pyc in wrapper(*args, **kwargs)
#      85                 warnings.warn('Update your `' + object_name +
#      86                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 87             return func(*args, **kwargs)
#      88         wrapper._original_function = func
#      89         return wrapper
#
# /home/omid/venv2/local/lib/python2.7/site-packages/Keras-2.1.2-py2.7.egg/keras/layers/convolutional.pyc in __init__(self, filters, kernel_size, strides, padding, data_format, dilation_rate, activation, use_bias, kernel_initializer, bias_initializer, kernel_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, bias_constraint, **kwargs)
#     456             kernel_constraint=kernel_constraint,
#     457             bias_constraint=bias_constraint,
# --> 458             **kwargs)
#     459         self.input_spec = InputSpec(ndim=4)
#     460
#
# /home/omid/venv2/local/lib/python2.7/site-packages/Keras-2.1.2-py2.7.egg/keras/layers/convolutional.pyc in __init__(self, rank, filters, kernel_size, strides, padding, data_format, dilation_rate, activation, use_bias, kernel_initializer, bias_initializer, kernel_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, bias_constraint, **kwargs)
#      98                  bias_constraint=None,
#      99                  **kwargs):
# --> 100         super(_Conv, self).__init__(**kwargs)
#     101         self.rank = rank
#     102         self.filters = filters
#
# /home/omid/venv2/local/lib/python2.7/site-packages/Keras-2.1.2-py2.7.egg/keras/engine/topology.pyc in __init__(self, **kwargs)
#     298                 else:
#     299                     batch_size = None
# --> 300                 batch_input_shape = (batch_size,) + tuple(kwargs['input_shape'])
#     301             self.batch_input_shape = batch_input_shape
#     302
#
# TypeError: 'NoneType' object is not iterable

# %%
for s in np.arange(0, 32):
    
    
    X_val = Normalized_data_reduced[s]
    X_val = np.expand_dims(X_val, axis=1)
    y_val = augmented_valence_labels[s]
    
    X_remaining_folds = Normalized_data_reduced[:s] + Normalized_data_reduced[s+1:]
    y_remaining_folds = augmented_valence_labels[:s] + augmented_valence_labels[s+1:]
    
    X_train = np.concatenate(X_remaining_folds)
    X_train = np.expand_dims(X_train, axis=1)
    
    y_train = np.concatenate(y_remaining_folds)

# %%
X_val.shape
# Out:
# (400, 1, 40, 29)
