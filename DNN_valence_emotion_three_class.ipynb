# %% [markdown]
# # Import required libraries

# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt
import time
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.models import load_model
from keras import metrics
from keras import regularizers
import models.nnmodels as nn
import utils.data as data

import gc
gc.enable()
seed = 0
np.random.seed(seed)
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Load data for three classes classification

# %%
print 'Loading DEAP dataset...'
subject_data_folds, valence_folds, arousal_folds = data.load_deap(32, 3)
print 'DEAP dataset is loaded.\n'

print 5*'#' + ' Dataset representation for each subject ' + 5*'#'
print '\nThere are {} subjects in the dataset.\n'.format(len(subject_data_folds))
print '(Trail/Video, Channel, Readings) : ', subject_data_folds[0].shape
print '(Trail/Video, label (valence or arousal)) : ', arousal_folds[0].shape
# Out:
# Loading DEAP dataset...
# DEAP dataset is loaded.
#
# ##### Dataset representation for each subject #####
#
# There are 32 subjects in the dataset.
#
# (Trail/Video, Channel, Readings) :  (40, 40, 8064)
# (Trail/Video, label (valence or arousal)) :  (40, 3)

# %% [markdown]
# # Reduce the features dimention (8064D >> 101D)
# ## Then Normalize the features

# %%
# Reduce the features dimension
print 'Mapping features into Gaussian with mean zero and unit variance...'
reduced_data_folds = data.normalize_features(subject_data_folds, flag=True)
print 'Normalization done.'
# Out:
# Mapping features into Gaussian with mean zero and unit variance...
# Normalization done.

# %% [markdown]
# # Train DNN model for three classes (low Valence / mid Valance / High Valence) classification

# %%
num_subjects = 32
batch_size = 250
epochs = 250
num_exp = 40
num_classes = 3



accuracies= []

print '##### Three Classes Classification for Valence emotion Using Deep Neural Network #####\n'

for s in np.arange(0, num_subjects):
    
    
    X_val = reduced_data_folds[s]
    y_val = valence_folds[s]
    
    X_remaining_folds = reduced_data_folds[:s] + reduced_data_folds[s+1:]
    y_remaining_folds = valence_folds[:s] + valence_folds[s+1:]
    
    X_train = np.concatenate(X_remaining_folds)
    y_train = np.concatenate(y_remaining_folds)
 
   

    key = 's'+str(s+1).zfill(2)+'_valence(3classes)'
      
    # Valence classification model for three classes    
    model = nn.DNN(num_classes=num_classes)
    
    # checkpoint
    filepath="../saved_models/best_model_for_{}.h5".format(key)
    
    print 'Training model to test on subject {} ...\n'.format(str(s+1).zfill(2))
    
    checkpoint = ModelCheckpoint(filepath, monitor='val_categorical_accuracy',
                                verbose=1, save_best_only=True, mode='max', period=20)
    callbacks_list = [checkpoint]
    
    hist = model.fit(X_train, y_train, 
             batch_size=batch_size,
             epochs=epochs,
             shuffle=True,
             verbose=0,
             validation_data=(X_val, y_val), callbacks=callbacks_list)
    
    
    
    model.load_weights(filepath)
    
    scores = model.evaluate(x=X_val, y=y_val)
    
    
    
    print '#### Result of DNN model for subject {} #####\n'.format(str(s+1).zfill(2))
    print "Loss: {} , Accuracy : {}%".format(scores[0], scores[1]*100)
    
    

    accuracies.append(scores[1])
    # summarize history for accuracy
    plt.plot(hist.history['categorical_accuracy'])
    plt.plot(hist.history['val_categorical_accuracy'])
    plt.title('Subject ' +str(s+1).zfill(2)+ ' DNN model accuracy for Valence')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    
    
    # summarize history for loss
    plt.plot(hist.history['loss'])
    plt.plot(hist.history['val_loss'])
    plt.title('Subject ' +str(s+1).zfill(2)+ ' DNN model loss for Valence')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

    del model
# Out:
# ##### Three Classes Classification for Valence emotion Using Deep Neural Network #####
#
# Training model to test on subject 01 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.47500, saving model to ../saved_models/best_model_for_s01_valence(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 171us/step
# #### Result of DNN model for subject 01 #####
#
# Loss: 1.03710026741 , Accuracy : 47.5
# Training model to test on subject 02 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.55000, saving model to ../saved_models/best_model_for_s02_valence(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy improved from 0.55000 to 0.57500, saving model to ../saved_models/best_model_for_s02_valence(3classes).h5
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 181us/step
# #### Result of DNN model for subject 02 #####
#
# Loss: 1.04256782532 , Accuracy : 57.5
# Training model to test on subject 03 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.40000, saving model to ../saved_models/best_model_for_s03_valence(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy improved from 0.40000 to 0.47500, saving model to ../saved_models/best_model_for_s03_valence(3classes).h5
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 185us/step
# #### Result of DNN model for subject 03 #####
#
# Loss: 1.04357132912 , Accuracy : 47.5
# Training model to test on subject 04 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.27500, saving model to ../saved_models/best_model_for_s04_valence(3classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.27500 to 0.35000, saving model to ../saved_models/best_model_for_s04_valence(3classes).h5
# Epoch 00060: val_categorical_accuracy improved from 0.35000 to 0.40000, saving model to ../saved_models/best_model_for_s04_valence(3classes).h5
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy improved from 0.40000 to 0.50000, saving model to ../saved_models/best_model_for_s04_valence(3classes).h5
# Epoch 00120: val_categorical_accuracy improved from 0.50000 to 0.52500, saving model to ../saved_models/best_model_for_s04_valence(3classes).h5
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 201us/step
# #### Result of DNN model for subject 04 #####
#
# Loss: 1.14375414848 , Accuracy : 52.5
# Training model to test on subject 05 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.50000, saving model to ../saved_models/best_model_for_s05_valence(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 193us/step
# #### Result of DNN model for subject 05 #####
#
# Loss: 1.03820443153 , Accuracy : 50.0
# Training model to test on subject 06 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.55000, saving model to ../saved_models/best_model_for_s06_valence(3classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.55000 to 0.60000, saving model to ../saved_models/best_model_for_s06_valence(3classes).h5
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 173us/step
# #### Result of DNN model for subject 06 #####
#
# Loss: 1.00732779503 , Accuracy : 60.0
# Training model to test on subject 07 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.57500, saving model to ../saved_models/best_model_for_s07_valence(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 166us/step
# #### Result of DNN model for subject 07 #####
#
# Loss: 0.975703167915 , Accuracy : 57.5
# Training model to test on subject 08 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.57500, saving model to ../saved_models/best_model_for_s08_valence(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 172us/step
# #### Result of DNN model for subject 08 #####
#
# Loss: 1.03177011013 , Accuracy : 57.5
# Training model to test on subject 09 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.55000, saving model to ../saved_models/best_model_for_s09_valence(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy improved from 0.55000 to 0.57500, saving model to ../saved_models/best_model_for_s09_valence(3classes).h5
# Epoch 00160: val_categorical_accuracy improved from 0.57500 to 0.60000, saving model to ../saved_models/best_model_for_s09_valence(3classes).h5
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 176us/step
# #### Result of DNN model for subject 09 #####
#
# Loss: 0.911644756794 , Accuracy : 60.0
# Training model to test on subject 10 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.47500, saving model to ../saved_models/best_model_for_s10_valence(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy improved from 0.47500 to 0.50000, saving model to ../saved_models/best_model_for_s10_valence(3classes).h5
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy improved from 0.50000 to 0.52500, saving model to ../saved_models/best_model_for_s10_valence(3classes).h5
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy improved from 0.52500 to 0.55000, saving model to ../saved_models/best_model_for_s10_valence(3classes).h5
# 40/40 [==============================] - 0s 173us/step
# #### Result of DNN model for subject 10 #####
#
# Loss: 1.04734071493 , Accuracy : 55.0
# Training model to test on subject 11 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.50000, saving model to ../saved_models/best_model_for_s11_valence(3classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.50000 to 0.52500, saving model to ../saved_models/best_model_for_s11_valence(3classes).h5
# Epoch 00060: val_categorical_accuracy improved from 0.52500 to 0.70000, saving model to ../saved_models/best_model_for_s11_valence(3classes).h5
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 168us/step
# #### Result of DNN model for subject 11 #####
#
# Loss: 0.929100441933 , Accuracy : 70.0
# Training model to test on subject 12 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.57500, saving model to ../saved_models/best_model_for_s12_valence(3classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.57500 to 0.70000, saving model to ../saved_models/best_model_for_s12_valence(3classes).h5
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy improved from 0.70000 to 0.72500, saving model to ../saved_models/best_model_for_s12_valence(3classes).h5
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 172us/step
# #### Result of DNN model for subject 12 #####
#
# Loss: 0.856226849556 , Accuracy : 72.5
# Training model to test on subject 13 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.42500, saving model to ../saved_models/best_model_for_s13_valence(3classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.42500 to 0.47500, saving model to ../saved_models/best_model_for_s13_valence(3classes).h5
# Epoch 00060: val_categorical_accuracy improved from 0.47500 to 0.50000, saving model to ../saved_models/best_model_for_s13_valence(3classes).h5
# Epoch 00080: val_categorical_accuracy improved from 0.50000 to 0.52500, saving model to ../saved_models/best_model_for_s13_valence(3classes).h5
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy improved from 0.52500 to 0.55000, saving model to ../saved_models/best_model_for_s13_valence(3classes).h5
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy improved from 0.55000 to 0.57500, saving model to ../saved_models/best_model_for_s13_valence(3classes).h5
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 189us/step
# #### Result of DNN model for subject 13 #####
#
# Loss: 0.900616669655 , Accuracy : 57.5
# Training model to test on subject 14 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.42500, saving model to ../saved_models/best_model_for_s14_valence(3classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.42500 to 0.50000, saving model to ../saved_models/best_model_for_s14_valence(3classes).h5
# Epoch 00060: val_categorical_accuracy improved from 0.50000 to 0.52500, saving model to ../saved_models/best_model_for_s14_valence(3classes).h5
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy improved from 0.52500 to 0.55000, saving model to ../saved_models/best_model_for_s14_valence(3classes).h5
# Epoch 00120: val_categorical_accuracy improved from 0.55000 to 0.57500, saving model to ../saved_models/best_model_for_s14_valence(3classes).h5
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy improved from 0.57500 to 0.60000, saving model to ../saved_models/best_model_for_s14_valence(3classes).h5
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 194us/step
# #### Result of DNN model for subject 14 #####
#
# Loss: 0.997225546837 , Accuracy : 60.0
# Training model to test on subject 15 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.62500, saving model to ../saved_models/best_model_for_s15_valence(3classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.62500 to 0.65000, saving model to ../saved_models/best_model_for_s15_valence(3classes).h5
# Epoch 00060: val_categorical_accuracy improved from 0.65000 to 0.70000, saving model to ../saved_models/best_model_for_s15_valence(3classes).h5
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 180us/step
# #### Result of DNN model for subject 15 #####
#
# Loss: 0.8272315979 , Accuracy : 70.0
# Training model to test on subject 16 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.37500, saving model to ../saved_models/best_model_for_s16_valence(3classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.37500 to 0.42500, saving model to ../saved_models/best_model_for_s16_valence(3classes).h5
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 189us/step
# #### Result of DNN model for subject 16 #####
#
# Loss: 1.17667706013 , Accuracy : 42.5
# Training model to test on subject 17 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.55000, saving model to ../saved_models/best_model_for_s17_valence(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 198us/step
# #### Result of DNN model for subject 17 #####
#
# Loss: 1.02643651962 , Accuracy : 55.0
# Training model to test on subject 18 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.45000, saving model to ../saved_models/best_model_for_s18_valence(3classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.45000 to 0.50000, saving model to ../saved_models/best_model_for_s18_valence(3classes).h5
# Epoch 00060: val_categorical_accuracy improved from 0.50000 to 0.52500, saving model to ../saved_models/best_model_for_s18_valence(3classes).h5
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 198us/step
# #### Result of DNN model for subject 18 #####
#
# Loss: 0.998392248154 , Accuracy : 52.5
# Training model to test on subject 19 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.50000, saving model to ../saved_models/best_model_for_s19_valence(3classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.50000 to 0.52500, saving model to ../saved_models/best_model_for_s19_valence(3classes).h5
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 207us/step
# #### Result of DNN model for subject 19 #####
#
# Loss: 0.914714920521 , Accuracy : 52.5
# Training model to test on subject 20 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.50000, saving model to ../saved_models/best_model_for_s20_valence(3classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.50000 to 0.55000, saving model to ../saved_models/best_model_for_s20_valence(3classes).h5
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy improved from 0.55000 to 0.57500, saving model to ../saved_models/best_model_for_s20_valence(3classes).h5
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 198us/step
# #### Result of DNN model for subject 20 #####
#
# Loss: 0.906811571121 , Accuracy : 57.5
# Training model to test on subject 21 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.47500, saving model to ../saved_models/best_model_for_s21_valence(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 179us/step
# #### Result of DNN model for subject 21 #####
#
# Loss: 1.02290856838 , Accuracy : 47.5
# Training model to test on subject 22 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.42500, saving model to ../saved_models/best_model_for_s22_valence(3classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.42500 to 0.52500, saving model to ../saved_models/best_model_for_s22_valence(3classes).h5
# Epoch 00060: val_categorical_accuracy improved from 0.52500 to 0.62500, saving model to ../saved_models/best_model_for_s22_valence(3classes).h5
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy improved from 0.62500 to 0.65000, saving model to ../saved_models/best_model_for_s22_valence(3classes).h5
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy improved from 0.65000 to 0.67500, saving model to ../saved_models/best_model_for_s22_valence(3classes).h5
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 179us/step
# #### Result of DNN model for subject 22 #####
#
# Loss: 0.980172908306 , Accuracy : 67.5
# Training model to test on subject 23 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.50000, saving model to ../saved_models/best_model_for_s23_valence(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 204us/step
# #### Result of DNN model for subject 23 #####
#
# Loss: 1.00457201004 , Accuracy : 50.0
# Training model to test on subject 24 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.37500, saving model to ../saved_models/best_model_for_s24_valence(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy improved from 0.37500 to 0.42500, saving model to ../saved_models/best_model_for_s24_valence(3classes).h5
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 184us/step
# #### Result of DNN model for subject 24 #####
#
# Loss: 1.18016209602 , Accuracy : 42.5
# Training model to test on subject 25 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.42500, saving model to ../saved_models/best_model_for_s25_valence(3classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.42500 to 0.47500, saving model to ../saved_models/best_model_for_s25_valence(3classes).h5
# Epoch 00060: val_categorical_accuracy improved from 0.47500 to 0.50000, saving model to ../saved_models/best_model_for_s25_valence(3classes).h5
# Epoch 00080: val_categorical_accuracy improved from 0.50000 to 0.55000, saving model to ../saved_models/best_model_for_s25_valence(3classes).h5
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy improved from 0.55000 to 0.57500, saving model to ../saved_models/best_model_for_s25_valence(3classes).h5
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 187us/step
# #### Result of DNN model for subject 25 #####
#
# Loss: 0.997903954983 , Accuracy : 57.5
# Training model to test on subject 26 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.47500, saving model to ../saved_models/best_model_for_s26_valence(3classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.47500 to 0.52500, saving model to ../saved_models/best_model_for_s26_valence(3classes).h5
# Epoch 00060: val_categorical_accuracy improved from 0.52500 to 0.55000, saving model to ../saved_models/best_model_for_s26_valence(3classes).h5
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 179us/step
# #### Result of DNN model for subject 26 #####
#
# Loss: 0.880569911003 , Accuracy : 55.0
# Training model to test on subject 27 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.60000, saving model to ../saved_models/best_model_for_s27_valence(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 183us/step
# #### Result of DNN model for subject 27 #####
#
# Loss: 0.963462686539 , Accuracy : 60.0
# Training model to test on subject 28 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.55000, saving model to ../saved_models/best_model_for_s28_valence(3classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.55000 to 0.62500, saving model to ../saved_models/best_model_for_s28_valence(3classes).h5
# Epoch 00060: val_categorical_accuracy improved from 0.62500 to 0.65000, saving model to ../saved_models/best_model_for_s28_valence(3classes).h5
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 215us/step
# #### Result of DNN model for subject 28 #####
#
# Loss: 0.891767430305 , Accuracy : 65.0
# Training model to test on subject 29 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.50000, saving model to ../saved_models/best_model_for_s29_valence(3classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.50000 to 0.55000, saving model to ../saved_models/best_model_for_s29_valence(3classes).h5
# Epoch 00060: val_categorical_accuracy improved from 0.55000 to 0.62500, saving model to ../saved_models/best_model_for_s29_valence(3classes).h5
# Epoch 00080: val_categorical_accuracy improved from 0.62500 to 0.65000, saving model to ../saved_models/best_model_for_s29_valence(3classes).h5
# Epoch 00100: val_categorical_accuracy improved from 0.65000 to 0.67500, saving model to ../saved_models/best_model_for_s29_valence(3classes).h5
# Epoch 00120: val_categorical_accuracy improved from 0.67500 to 0.70000, saving model to ../saved_models/best_model_for_s29_valence(3classes).h5
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 196us/step
# #### Result of DNN model for subject 29 #####
#
# Loss: 0.823496413231 , Accuracy : 70.0
# Training model to test on subject 30 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.45000, saving model to ../saved_models/best_model_for_s30_valence(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy did not improve
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy improved from 0.45000 to 0.47500, saving model to ../saved_models/best_model_for_s30_valence(3classes).h5
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 202us/step
# #### Result of DNN model for subject 30 #####
#
# Loss: 0.980629658699 , Accuracy : 47.5
# Training model to test on subject 31 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.47500, saving model to ../saved_models/best_model_for_s31_valence(3classes).h5
# Epoch 00040: val_categorical_accuracy improved from 0.47500 to 0.62500, saving model to ../saved_models/best_model_for_s31_valence(3classes).h5
# Epoch 00060: val_categorical_accuracy improved from 0.62500 to 0.65000, saving model to ../saved_models/best_model_for_s31_valence(3classes).h5
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy improved from 0.65000 to 0.67500, saving model to ../saved_models/best_model_for_s31_valence(3classes).h5
# Epoch 00160: val_categorical_accuracy improved from 0.67500 to 0.70000, saving model to ../saved_models/best_model_for_s31_valence(3classes).h5
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy improved from 0.70000 to 0.72500, saving model to ../saved_models/best_model_for_s31_valence(3classes).h5
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 193us/step
# #### Result of DNN model for subject 31 #####
#
# Loss: 0.807934856415 , Accuracy : 72.5
# Training model to test on subject 32 ...
#
# Epoch 00020: val_categorical_accuracy improved from -inf to 0.50000, saving model to ../saved_models/best_model_for_s32_valence(3classes).h5
# Epoch 00040: val_categorical_accuracy did not improve
# Epoch 00060: val_categorical_accuracy improved from 0.50000 to 0.55000, saving model to ../saved_models/best_model_for_s32_valence(3classes).h5
# Epoch 00080: val_categorical_accuracy did not improve
# Epoch 00100: val_categorical_accuracy did not improve
# Epoch 00120: val_categorical_accuracy did not improve
# Epoch 00140: val_categorical_accuracy did not improve
# Epoch 00160: val_categorical_accuracy did not improve
# Epoch 00180: val_categorical_accuracy did not improve
# Epoch 00200: val_categorical_accuracy did not improve
# Epoch 00220: val_categorical_accuracy did not improve
# Epoch 00240: val_categorical_accuracy did not improve
# 40/40 [==============================] - 0s 206us/step
# #### Result of DNN model for subject 32 #####
#
# Loss: 0.962343931198 , Accuracy : 55.0

# %%
print np.argmin(accuracies)+1, np.argmax(accuracies)+1
print min(accuracies), max(accuracies)
print reduce(lambda x, y: x + y, accuracies) / len(accuracies)
accuracies
# Out:
# 16 12
# 0.425 0.725
# 0.5703125
# [0.47499999999999998,
#  0.57499999999999996,
#  0.47499999999999998,
#  0.52500000000000002,
#  0.5,
#  0.59999999999999998,
#  0.57499999999999996,
#  0.57499999999999996,
#  0.59999999999999998,
#  0.55000000000000004,
#  0.69999999999999996,
#  0.72499999999999998,
#  0.57499999999999996,
#  0.59999999999999998,
#  0.69999999999999996,
#  0.42499999999999999,
#  0.55000000000000004,
#  0.52500000000000002,
#  0.52500000000000002,
#  0.57499999999999996,
#  0.47499999999999998,
#  0.67500000000000004,
#  0.5,
#  0.42499999999999999,
#  0.57499999999999996,
#  0.55000000000000004,
#  0.59999999999999998,
#  0.65000000000000002,
#  0.69999999999999996,
#  0.47499999999999998,
#  0.72499999999999998,
#  0.55000000000000004]
